# %%
# @hidden_cell
# The project token is an authorization token that is used to access project resources like data sources, connections, and used by platform APIs.
from project_lib import Project
project = Project(project_id='e285d04e-8405-4384-a49d-4dda639b7191', project_access_token='p-47aff461317d8707510d69f1fbbd35a48d608ccb')
pc = project.project_context

# %% [markdown]
# ![ibm cloud logo](./images/ibm-cloud.png)
#
# # Case Study - Data ingestion

# %% [markdown]
# The goal of this case study is to put into practice the important concepts from module 1.  We will go through the basic process that begins with refining the business opportunity and ensuring that it is articulated using a scientific thought process.
#
# The business opportunity and case study was first mentioned in Unit 2 of module 1 and like the AAVIAL company itself these data were created for learning purposes.  We will be using the AAVAIL example as a basis for this case study.  [Watch the video again](https://vimeo.com/348708995) if you need a refresher.  You will be gathering data from several provided sources, staging it for quality assurance and saving it in a target destination that is most appropriate.
#
# Watch the video to review the important concepts from the units you just covered and to see an overview of the objectives for this case study.

# %%
from IPython.display import IFrame
IFrame('https://player.vimeo.com/video/354996550', width=600,height=400)
# Out:
#         <iframe
#             width="600"
#             height="400"
#             src="https://player.vimeo.com/video/354996550"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## Case study overall objectives
#
# 1. Gather all relevant data from the sources of provided data
# 2. Implement several checks for quality assurance
# 3. Take the initial steps towards automation of the ingestion pipeline
#
# ## Getting started
#
# Download this notebook and open it locally using a Jupyter server. Alternatively you may use Watson Studio.  To make using Watson Studio easier we have provided a zip archive file containing the files needed to complete this case study in Watson Studio. See the [Getting started with Watson Studio](m1-u5-5-watson-studio.rst) page.
#
# **You will need the following files to complete this case study**
#
# * [m1-u6-case-study.ipynb](m1-u6-case-study.ipynb)
# * [m1-u6-case-study-solution.ipynb](./notebooks/m1-u6-case-study-solution.ipynb)
# * [aavail-customers.db](./data/aavail-customers.db)
# * [aavail-steams.csv](./data/aavail-streams.csv)
#
# 1. Fill in all of the places in this notebook marked with ***YOUR CODE HERE*** or ***YOUR ANSWER HERE***
# 2. When you have finished the case study there will be a short quiz
#
# You may review the rest of this content as part of the notebook, but once you are ready to get started be ensure that you are working with a *live* version either as part of Watson Studio or locally.

# %% [markdown]
# ## Data Sources
#
# The data you will be sourcing from is contained in two sources.
#
# 1. A database ([SQLite](https://www.sqlite.org/index.html)) of `customer` data
# 2. A [CSV file](https://en.wikipedia.org/wiki/Comma-separated_values) of `stream` level data
#
#    >You will create a simple data pipeline that
#    (1) simplifies the data for future analysis
#    (2) performs quality assurance checks.
#
# The process of building *the data ingestion pipeline* entails extracting data, transforming it, and loading it into an appropriate data storage technology.  When constructing a pipeline it is important to keep in mind that they generally process data in batches.  For example, data may be compiled during the day and the batch could be processed during the night.  The data pipeline may also be optimized to execute as a streaming computation (i.e., every event is handled as it occurs).

# %% [markdown]
# ## PART 1: Gathering the data
#
# The following is an [Entity Relationship Diagram (ERD)](https://en.wikipedia.org/wiki/Entity%E2%80%93relationship_model) that details the tables and contents of the database.
#
# <img src="./images/aavail-schema.svg" alt="customer database schema" style="width: 600px;"/>

# %%
## all the imports you will need for this case study
import os
import pandas as pd
import numpy as np
import sqlite3

# %% [markdown]
# Much of the data exist in a database.  You can connect to is using the `sqlite3` Python package with the function shown below.  Note that is is good practice to wrap your connect functions in a [try-except statement](https://docs.python.org/3/tutorial/errors.html) to cleanly handle exceptions.

# %%
DATA_DIR = pc.home + '/data'

# %%
import os

def copy_data_to_files(p):
    data_dir = p.project_context.home + '/data'

    if not os.path.exists( data_dir ):
        os.makedirs( data_dir )
    
    for fn in [data_asset['name'] for data_asset in p.get_files()]:
        with open( data_dir + '/' + fn, 'wb') as w:
            w.write(p.get_file(fn).read())
            
copy_data_to_files(project)

# %%
print(os.getcwd())
print(os.listdir())
print(os.listdir("/home/dsxuser/data"))
# Out:
# /home/dsxuser/work
# []
# ['aavail-customers.db', 'aavail-streams.csv']

# %%
def connect_db(file_path):
    try:
        conn = sqlite3.connect(file_path)
        print("...successfully connected to db\n")
    except Error as e:
        print("...unsuccessful connection\n",e)
    
    return(conn)

# %%
## make the connection to the database
conn = connect_db(DATA_DIR + '/aavail-customers.db')

## print the table names
tables = [t[0] for t in conn.execute("SELECT name FROM sqlite_master WHERE type='table';")]
print(tables)
# Out:
# ...successfully connected to db
#
# ['CUSTOMERS', 'INVOICES', 'INVOICE_ITEMS']

# %%
df_invoice_items = pd.read_sql_query("SELECT invoice_item_id, invoice_item FROM INVOICE_ITEMS;", conn)
customer_types = df_invoice_items.set_index("invoice_item_id").T.to_dict("index")['invoice_item']

# %%
df_invoices = pd.read_sql_query("SELECT * FROM INVOICES;", conn)
df_invoices.head()

# df_invoices[["customer_id","invoice_item_id"]].invoice_item_id.replace(customer_types)
# Out:
#    generated_id  invoice_item_id  customer_id signup_date last_stream
# 0             1                3            1  2018-11-29  2019-03-18
# 1             2                3            2  2019-03-28  2019-06-08
# 2             3                2            3  2018-12-20  2019-05-31
# 3             4                3            4  2018-01-04  2018-03-29
# 4             5                1            5  2019-03-08  2019-05-24

# %% [markdown]
# ### QUESTION 1:
#
# **extract the relevant data from the DB**
#
# Query the database and extract the following data into a [Pandas DataFrame](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.html).
#
# * Customer ID (integer)
# * Last name
# * First name
# * DOB
# * City
# * State
# * Country (the name NOT the country_id)
# * Gender
#
# Remember that that SQL is case-insensitive, but it is traditional to use ALL CAPS for SQL keywords. It is also a convention to end SQL statements with a semi-colon.
#
# #### Resources
#
# * [W3 schools SQL tutorial](https://www.w3schools.com/sql)
# * [W3 schools SQL joins](https://www.w3schools.com/sql/sql_join.asp)

# %%
## YOUR CODE HERE

df_customers = pd.read_sql_query("SELECT customer_id, last_name, first_name, DOB, city, state, country, gender FROM CUSTOMERS", conn)
df_customers.head()
# Out:
#    customer_id    last_name first_name       DOB       city           state  \
# 0            1         Todd      Kasen  07/30/98  Rock Hill  South Carolina
# 1            2        Garza     Ensley  04/12/89  singapore            None
# 2            3        Carey    Lillian  09/12/97     Auburn         Alabama
# 3            4  Christensen       Beau  01/28/99  Hempstead        New York
# 4            5       Gibson    Ernesto  03/23/98  singapore            None
#
#          country gender
# 0  united_states      m
# 1      singapore      f
# 2  united_states      f
# 3  united_states      m
# 4      singapore      m

# %% [markdown]
# ### QUESTION 2:
#
# **Extract the relevant data from the CSV file**
#
# For each ```customer_id``` determine if a customer has stopped their subscription or not and save it in a dictionary or another data container.

# %%
df_streams = pd.read_csv(DATA_DIR + '/aavail-streams.csv')
df_streams.head()
# Out:
#    customer_id  stream_id        date  subscription_stopped
# 0            1       1356  2018-12-01                     0
# 1            1       1540  2018-12-04                     0
# 2            1       1395  2018-12-11                     0
# 3            1       1255  2018-12-22                     0
# 4            1       1697  2018-12-23                     0

# %%
## YOUR CODE HERE
cust_status = df_streams.groupby(['customer_id'], sort=False)['subscription_stopped'].max().to_dict()

# %% [markdown]
# ## PART 2: Checks for quality assurance
#
# Sometimes it is known in advance which types of data integrity issues to expect, but other times it is during the Exploratory Data Analysis (EDA) process that these issues are identified.  After extracting data it is important to include checks for quality assurance even on the first pass through the AI workflow.  Here you will combine the data into a single structure and provide a couple checks for quality assurance.
#
# ### QUESTION 3:
#
# **Implement checks for quality assurance**
#
# 1. Remove any repeat customers based on ```customer_id```
# 2. Remove stream data that do not have an associated ```stream_id```
# 3. Check for missing values

# %% [markdown]
# ### 1. Remove repeat customers based on ```customer_id```

# %%
num_dupes = df_customers.duplicated(['customer_id']).sum()
print(f'...Removing {num_dupes} duplicate customer records')
df_customers = df_customers[~df_customers.duplicated(['customer_id'])]
# Out:
# ...Removing 7 duplicate customer records

# %% [markdown]
# ### 2. Remove stream data that do not have an associated ```stream_id```

# %%
num_missing_stream_id = df_streams['stream_id'].isna().sum()
print(f'...Removing {num_missing_stream_id} streams with missing IDs')
df_streams = df_streams[~df_streams['stream_id'].isna()]

df_streams.head()
# Out:
# ...Removing 0 streams with missing IDs
#    customer_id  stream_id        date  subscription_stopped
# 0            1       1356  2018-12-01                     0
# 1            1       1540  2018-12-04                     0
# 2            1       1395  2018-12-11                     0
# 3            1       1255  2018-12-22                     0
# 4            1       1697  2018-12-23                     0

# %% [markdown]
# ### 3. Check for missing values

# %%
#state is missing for country outside US
df_customers.drop(['state'], axis=1).isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# ### QUESTION 4:
#
# **combine the data into a single data structure**
#
# For this example, the two most convenient structures for this task are Pandas dataframes and NumPy arrays.  At a minimum ensure that your structure accommodates the following.
#
# 1. A column for `customer_id`
# 2. A column for `country`
# 3. A column for ```age``` that is created from ```DOB```
# 4. A column ```customer_name``` that is created from ```first_name``` and ```last_name```
# 5. A column to indicate churn called ```is_subscriber```
# 7. A column that indicates ```subscriber_type``` that comes from ```invoice_item```
# 6. A column to indicate the total ```num_streams```
#
# #### Resources
#
# * [Python's datetime library](https://docs.python.org/3/library/datetime.html)
# * [NumPy's datetime data type](https://docs.scipy.org/doc/numpy/reference/arrays.datetime.html)

# %%
## YOUR CODE HERE
from datetime import date, datetime

def calculate_age(dob):

    dob = datetime.strptime(dob, "%m/%d/%y").date()
    today = date.today()
    
    min_csr_age = 10
    age_ceiling = today.year - min_csr_age
    
    if dob.year > age_ceiling:
        dob = dob.replace(year=dob.year-100)
        
    return today.year - dob.year - ((today.month, today.day) < (dob.month, dob.day))

# %%
df_customers['age'] = df_customers['DOB'].apply(calculate_age)

df_customers.head()
# Out:
#    customer_id    last_name first_name       DOB       city           state  \
# 0            1         Todd      Kasen  07/30/98  Rock Hill  South Carolina
# 1            2        Garza     Ensley  04/12/89  singapore            None
# 2            3        Carey    Lillian  09/12/97     Auburn         Alabama
# 3            4  Christensen       Beau  01/28/99  Hempstead        New York
# 4            5       Gibson    Ernesto  03/23/98  singapore            None
#
#          country gender  age
# 0  united_states      m   21
# 1      singapore      f   30
# 2  united_states      f   22
# 3  united_states      m   21
# 4      singapore      m   21

# %%
print(df_customers['age'].max())
print(df_customers['age'].min())
# Out:
# 56
# 13

# %%
df_customers["customer_name"] = df_customers["first_name"] + " " + df_customers["last_name"]
df_customers.head()
# Out:
#    customer_id    last_name first_name       DOB       city           state  \
# 0            1         Todd      Kasen  07/30/98  Rock Hill  South Carolina
# 1            2        Garza     Ensley  04/12/89  singapore            None
# 2            3        Carey    Lillian  09/12/97     Auburn         Alabama
# 3            4  Christensen       Beau  01/28/99  Hempstead        New York
# 4            5       Gibson    Ernesto  03/23/98  singapore            None
#
#          country gender  age     customer_name
# 0  united_states      m   21        Kasen Todd
# 1      singapore      f   30      Ensley Garza
# 2  united_states      f   22     Lillian Carey
# 3  united_states      m   21  Beau Christensen
# 4      singapore      m   21    Ernesto Gibson

# %%
df_customers["is_subscriber"] = df_customers['customer_id'].map(cust_status)
df_customers.head()
# Out:
#    customer_id    last_name first_name       DOB       city           state  \
# 0            1         Todd      Kasen  07/30/98  Rock Hill  South Carolina
# 1            2        Garza     Ensley  04/12/89  singapore            None
# 2            3        Carey    Lillian  09/12/97     Auburn         Alabama
# 3            4  Christensen       Beau  01/28/99  Hempstead        New York
# 4            5       Gibson    Ernesto  03/23/98  singapore            None
#
#          country gender  age     customer_name  is_subscriber
# 0  united_states      m   21        Kasen Todd              0
# 1      singapore      f   30      Ensley Garza              1
# 2  united_states      f   22     Lillian Carey              0
# 3  united_states      m   21  Beau Christensen              0
# 4      singapore      m   21    Ernesto Gibson              0

# %%
# df_customer_types = pd.DataFrame(df_invoices[["customer_id","invoice_item_id"]].invoice_item_id.replace(customer_types))
df_subscriber_types = df_invoices.loc[:,["customer_id", "invoice_item_id"]]
df_subscriber_types["subscriber_type"] = df_subscriber_types.invoice_item_id.replace(customer_types)
df_subscriber_types = df_subscriber_types[["customer_id", "subscriber_type"]]

df_customers = pd.merge(df_customers, df_subscriber_types, on='customer_id')
df_customers.head()
# Out:
#    customer_id    last_name first_name       DOB       city           state  \
# 0            1         Todd      Kasen  07/30/98  Rock Hill  South Carolina
# 1            2        Garza     Ensley  04/12/89  singapore            None
# 2            3        Carey    Lillian  09/12/97     Auburn         Alabama
# 3            4  Christensen       Beau  01/28/99  Hempstead        New York
# 4            5       Gibson    Ernesto  03/23/98  singapore            None
#
#          country gender  age     customer_name  is_subscriber  \
# 0  united_states      m   21        Kasen Todd              0
# 1      singapore      f   30      Ensley Garza              1
# 2  united_states      f   22     Lillian Carey              0
# 3  united_states      m   21  Beau Christensen              0
# 4      singapore      m   21    Ernesto Gibson              0
#
#     subscriber_type
# 0  aavail_unlimited
# 1  aavail_unlimited
# 2    aavail_premium
# 3  aavail_unlimited
# 4      aavail_basic

# %%
# pd.merge(df_customers, df_streams.groupby(['customer_id'], sort=False).count().reset_index(), on='customer_id')
df_customers = pd.merge(df_customers,df_streams.groupby(['customer_id'], sort=False)['stream_id'].count().reset_index().rename(columns={'stream_id':'num_streams'}), on='customer_id')
df_customers.head()
# Out:
#    customer_id    last_name first_name       DOB       city           state  \
# 0            1         Todd      Kasen  07/30/98  Rock Hill  South Carolina
# 1            2        Garza     Ensley  04/12/89  singapore            None
# 2            3        Carey    Lillian  09/12/97     Auburn         Alabama
# 3            4  Christensen       Beau  01/28/99  Hempstead        New York
# 4            5       Gibson    Ernesto  03/23/98  singapore            None
#
#          country gender  age     customer_name  is_subscriber  \
# 0  united_states      m   21        Kasen Todd              0
# 1      singapore      f   30      Ensley Garza              1
# 2  united_states      f   22     Lillian Carey              0
# 3  united_states      m   21  Beau Christensen              0
# 4      singapore      m   21    Ernesto Gibson              0
#
#     subscriber_type  num_streams
# 0  aavail_unlimited           21
# 1  aavail_unlimited           16
# 2    aavail_premium           25
# 3  aavail_unlimited           18
# 4      aavail_basic           21

# %%
df_customers.to_csv(os.path.join(DATA_DIR, "processed_data.csv"))

# %% [markdown]
# ## PART 3: Automating the process
#
# To ensure that you code can be used to automate this process.  First you will save you dataframe or numpy array as a CSV file.
#
# ### QUESTION 5:
#
# **Take the initial steps towards automation**
#
# 1. Save your cleaned, combined data as a CSV file.
# 2. From the code above create a function or class that performs all of the steps given a database file and a streams CSV file.
# 3. Run the function in batches and write a check to ensure you got the same result that you did in the code above.
#
# There will be some logic involved to ensure that you do not write the same data twice to the target CSV file.
#
# Shown below is some code that will split your streams file into two batches.

# %%
# body = client_bfb337e9d3b24554ad9a816fe610a744.get_object(Bucket='aienterpriseworkflowmodule1casest-donotdelete-pr-qwt6qhnjsctfni',Key='aavail-streams.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
# if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

## code to split the streams csv into batches
DATA_DIR = "/home/dsxuser/data"
df_all = pd.read_csv(os.path.join(DATA_DIR, 'aavail-streams.csv'))

half = int(round(df_all.shape[0] * 0.5))
df_part1 = df_all[:half]
df_part2 = df_all[half:]

df_part1.size
df_part1.to_csv(os.path.join(DATA_DIR, 'aavail-streams-1.csv'), index=False)
df_part2.to_csv(os.path.join(DATA_DIR, 'aavail-streams-2.csv'), index=False)

# %%
os.getcwd()
print(os.listdir("/home/dsxuser/data"))
# Out:
# ['aavail-streams-2.csv', 'processed_data.csv', 'aavail-customers.db', 'aavail-streams-1.csv', 'aavail-streams.csv']

# %%
# %%writefile aavail-data-ingestor.py
#!/usr/bin/env python

import os
import pandas as pd
import numpy as np
import sqlite3
import sys
import getopt
from datetime import date, datetime

DATA_DIR = '/home/dsxuser/data'

def connect_db(file_path):
    try:
        conn = sqlite3.connect(file_path)
        print("...successfully connected to db\n")
    except Error as e:
        print("...unsuccessful connection\n",e)
    
    return(conn)

def calculate_age(dob):

    dob = datetime.strptime(dob, "%m/%d/%y").date()
    today = date.today()
    
    min_csr_age = 10
    age_ceiling = today.year - min_csr_age
    
    if dob.year > age_ceiling:
        dob = dob.replace(year=dob.year-100)
        
    return today.year - dob.year - ((today.month, today.day) < (dob.month, dob.day))

def process_data(db, stream_csv):
    # connect to customer db
    conn = connect_db(db)
    
    # read tables as dataframes
    df_customers = pd.read_sql_query("SELECT customer_id, last_name, first_name, DOB, city, state, country, gender FROM CUSTOMERS", conn)
    df_invoices = pd.read_sql_query("SELECT * FROM INVOICES;", conn)
    df_invoice_items = pd.read_sql_query("SELECT invoice_item_id, invoice_item FROM INVOICE_ITEMS;", conn)
    
    # get subscriber types from invoice items
    subscription_types = df_invoice_items.set_index("invoice_item_id").T.to_dict("index")['invoice_item']
    
    # get streams data
    df_streams = pd.read_csv(stream_csv)

    # get subscriber status from streams
    subscriber_status = df_streams.groupby(['customer_id'], sort=False)['subscription_stopped'].max().to_dict()
    
    # remove duplicate customers
    num_dupes = df_customers.duplicated(['customer_id']).sum()
    print(f'...Removing {num_dupes} duplicate customer records')
    df_customers = df_customers[~df_customers.duplicated(['customer_id'])]
    
    # remove stream data w no stream id
    num_missing_stream_id = df_streams['stream_id'].isna().sum()
    print(f'...Removing {num_missing_stream_id} streams with missing IDs')
    df_streams = df_streams[~df_streams['stream_id'].isna()]
    
    # check for missing values
    print('...Number of missing values: ', df_customers.drop(['state'], axis=1).isnull().sum().sum())           #state is missing for country outside US

    # enrich customer records
    df_customers['age'] = df_customers['DOB'].apply(calculate_age)
    df_customers["customer_name"] = df_customers["first_name"] + " " + df_customers["last_name"]
    df_customers["is_subscriber"] = df_customers['customer_id'].map(subscriber_status)
    
    # subscription type
    df_subscriber_types = df_invoices.loc[:,["customer_id", "invoice_item_id"]]
    df_subscriber_types["subscriber_type"] = df_subscriber_types.invoice_item_id.replace(subscription_types)
    df_subscriber_types = df_subscriber_types[["customer_id", "subscriber_type"]]    
    df_customers = pd.merge(df_customers, df_subscriber_types, on='customer_id')
    
    # number of streams
    df_customers = pd.merge(df_customers,df_streams.groupby(['customer_id'], sort=False)['stream_id'].count().reset_index().rename(columns={'stream_id':'num_streams'}), on='customer_id')

    return df_customers

def update_target(target_file,df_clean,overwrite=False):
    """
    update line by line in case data are large
    """

    if overwrite or not os.path.exists(target_file):
        df_clean.to_csv(target_file,index=False)   
    else:
        df_target = pd.read_csv(target_file)
        df_target.to_csv(target_file, mode='a',index=False)
         
if __name__ == "__main__":
  
    ## collect args
    arg_string = "%s -d db_filepath -s streams_filepath"%sys.argv[0]
    try:
        optlist, args = getopt.getopt(sys.argv[1:],'d:s:')
    except getopt.GetoptError:
        print(getopt.GetoptError)
        raise Exception(arg_string)

    ## handle args
    streams_file = None
    db_file = None
    for o, a in optlist:
        if o == '-d':
            db_file = a
        if o == '-s':
            streams_file = a
    streams_file = os.path.join(DATA_DIR,streams_file)
    db_file = os.path.join(DATA_DIR,db_file)
    target_file = os.path.join(DATA_DIR,"aavail-target.csv")
    
    ## process data
    df_clean = process_data(db_file, streams_file)
    
    ## write
    update_target(target_file,df_clean,overwrite=False)
    print("done")
# Out:
# Writing aavail-data-ingestor.py

# %%
db_file = os.path.join(DATA_DIR, 'aavail-customers.db')
streams_csv = os.path.join(DATA_DIR, 'aavail-streams.csv')

process_data(db_file, streams_csv).to_csv(os.path.join(DATA_DIR, "processed_data.csv"))
# !wc -l ../data/processed_data.csv
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-250063e68144> in <module>
#       2 streams_csv = os.path.join(DATA_DIR, 'aavail-streams.csv')
#       3
# ----> 4 process_data(db_file, streams_csv).to_csv(os.path.join(DATA_DIR, "processed_data.csv"))
#       5 get_ipython().system('wc -l ../data/processed_data.csv')
#
# NameError: name 'process_data' is not defined

# %%
# !python aavail-data-ingestor.py -d aavail-customers.db -s aavail-streams.csv
# Out:
# ...successfully connected to db
#
# ...Removing 7 duplicate customer records
# ...Removing 0 streams with missing IDs
# ...Number of missing values:  0
# done

# %%
# !mv ../data/aavail-target.csv ../data/aavail-target-complete.csv
# !wc -l ../data/aavail-target-complete.csv
# Out:
# 1001 ../data/aavail-target-complete.csv

# %%
# !python aavail-data-ingestor.py -d aavail-customers.db -s aavail-streams-1.csv
# !wc -l ../data/aavail-target.csv
# !python aavail-data-ingestor.py -d aavail-customers.db -s aavail-streams-2.csv
# !wc -l ../data/aavail-target.csv
# Out:
# ...successfully connected to db
#
# ...Removing 7 duplicate customer records
# ...Removing 0 streams with missing IDs
# ...Number of missing values:  0
# done
# 498 ../data/aavail-target.csv
# ...successfully connected to db
#
# ...Removing 7 duplicate customer records
# ...Removing 0 streams with missing IDs
# ...Number of missing values:  0
# done
# 996 ../data/aavail-target.csv

# %%
# !python aavail-data-ingestor.py -d aavail-customers.db -s aavail-streams-1.csv
# !wc -l ../data/aavail-target.csv
# Out:
# ...successfully connected to db
#
# ...Removing 7 duplicate customer records
# ...Removing 0 streams with missing IDs
# ...Number of missing values:  0
# done
# 498 ../data/aavail-target.csv

# %%
# !head ../data/aavail-target.csv
# Out:
# customer_id,last_name,first_name,DOB,city,state,country,gender,age,customer_name,is_subscriber,subscriber_type,num_streams
# 1,Todd,Kasen,07/30/98,Rock Hill,South Carolina,united_states,m,21,Kasen Todd,0,aavail_unlimited,21
# 2,Garza,Ensley,04/12/89,singapore,,singapore,f,30,Ensley Garza,1,aavail_unlimited,16
# 3,Carey,Lillian,09/12/97,Auburn,Alabama,united_states,f,22,Lillian Carey,0,aavail_premium,25
# 4,Christensen,Beau,01/28/99,Hempstead,New York,united_states,m,21,Beau Christensen,0,aavail_unlimited,18
# 5,Gibson,Ernesto,03/23/98,singapore,,singapore,m,21,Ernesto Gibson,0,aavail_basic,21
# 6,Murray,Deshawn,09/18/97,Portland,Maine,united_states,m,22,Deshawn Murray,0,aavail_premium,22
# 7,Tate,Daxton,12/23/70,singapore,,singapore,m,49,Daxton Tate,1,aavail_unlimited,16
# 8,Small,Tenley,07/21/72,Paterson,New Jersey,united_states,f,47,Tenley Small,0,aavail_basic,21
# 9,Chase,Kyra,05/19/98,Temple,Texas,united_states,f,21,Kyra Chase,0,aavail_premium,4

# %%
# !csvdiff --style=summary ./data/processed_data.csv ../data/aavail-target.csv

# %%
import difflib
csv1 = open(os.path.join(DATA_DIR, "aavail-target-complete.csv"), 'r').readlines()
csv2 = open(os.path.join(DATA_DIR, "aavail-target.csv"), 'r').readlines()
    
for line in csv1:
    print(difflib.unifiedline)
# Out:
# ---
#
# +++
#
# @@ -1,1001 +1,996 @@
#
#  customer_id,last_name,first_name,DOB,city,state,country,gender,age,customer_name,is_subscriber,subscriber_type,num_streams
#
# -1,Todd,Kasen,07/30/98,Rock Hill,South Carolina,united_states,m,21,Kasen Todd,0,aavail_unlimited,21
#
# -2,Garza,Ensley,04/12/89,singapore,,singapore,f,30,Ensley Garza,1,aavail_unlimited,16
#
# -3,Carey,Lillian,09/12/97,Auburn,Alabama,united_states,f,22,Lillian Carey,0,aavail_premium,25
#
# -4,Christensen,Beau,01/28/99,Hempstead,New York,united_states,m,21,Beau Christensen,0,aavail_unlimited,18
#
# -5,Gibson,Ernesto,03/23/98,singapore,,singapore,m,21,Ernesto Gibson,0,aavail_basic,21
#
# -6,Murray,Deshawn,09/18/97,Portland,Maine,united_states,m,22,Deshawn Murray,0,aavail_premium,22
#
# -7,Tate,Daxton,12/23/70,singapore,,singapore,m,49,Daxton Tate,1,aavail_unlimited,16
#
# -8,Small,Tenley,07/21/72,Paterson,New Jersey,united_states,f,47,Tenley Small,0,aavail_basic,21
#
# -9,Chase,Kyra,05/19/98,Temple,Texas,united_states,f,21,Kyra Chase,0,aavail_premium,4
#
# -10,Barber,London,07/17/93,Somerville,Massachusetts,united_states,f,26,London Barber,0,aavail_basic,19
#
# -11,Rivas,Rohan,01/23/05,Pawtucket,Rhode Island,united_states,m,15,Rohan Rivas,0,aavail_premium,19
#
# -12,Ross,Romina,05/05/80,singapore,,singapore,f,39,Romina Ross,0,aavail_basic,19
#
# -13,Moore,Liberty,03/04/99,Bristol,Connecticut,united_states,f,21,Liberty Moore,0,aavail_basic,21
#
# -14,Huber,Yusuf,07/22/00,Woburn,Massachusetts,united_states,m,19,Yusuf Huber,0,aavail_basic,22
#
# -15,Suarez,Brantley,11/04/96,Decatur,Illinois,united_states,m,23,Brantley Suarez,1,aavail_premium,21
#
# -16,Ray,Skyler,05/08/97,Queen Creek,Arizona,united_states,m,22,Skyler Ray,0,aavail_basic,18
#
# -17,Boyd,Joel,07/18/92,Ormond Beach,Florida,united_states,m,27,Joel Boyd,0,aavail_basic,20
#
# -18,Torres,Zayne,10/11/74,singapore,,singapore,m,45,Zayne Torres,1,aavail_premium,15
#
# -19,Cross,Madden,03/15/91,Sierra Vista,Arizona,united_states,m,28,Madden Cross,0,aavail_unlimited,22
#
# -20,Eaton,Jabari,04/29/99,Beaverton,Oregon,united_states,m,20,Jabari Eaton,0,aavail_basic,20
#
# -21,Hickman,Claudia,06/08/81,singapore,,singapore,f,38,Claudia Hickman,0,aavail_unlimited,16
#
# -22,Parker,Darwin,05/27/78,singapore,,singapore,m,41,Darwin Parker,0,aavail_unlimited,20
#
# -23,Pruitt,Josiah,05/16/97,San Marcos,Texas,united_states,m,22,Josiah Pruitt,0,aavail_unlimited,20
#
# -24,Landry,Derek,08/07/96,singapore,,singapore,m,23,Derek Landry,1,aavail_unlimited,18
#
# -25,Dejesus,Sage,07/12/99,singapore,,singapore,m,20,Sage Dejesus,1,aavail_unlimited,18
#
# -26,Adams,Mikaela,05/05/95,Roseville,Michigan,united_states,f,24,Mikaela Adams,0,aavail_premium,25
#
# -27,Lee,Jimmy,07/15/98,Henderson,Nevada,united_states,m,21,Jimmy Lee,1,aavail_basic,24
#
# -28,Hubbard,Devin,11/26/00,Sioux City,Iowa,united_states,m,19,Devin Hubbard,0,aavail_premium,23
#
# -29,Miles,Kameron,09/16/98,singapore,,singapore,m,21,Kameron Miles,0,aavail_unlimited,11
#
# -30,Jennings,Francisco,03/31/80,Orland Park,Illinois,united_states,m,39,Francisco Jennings,0,aavail_unlimited,20
#
# -31,Rubio,Dalary,07/12/00,Indio,California,united_states,f,19,Dalary Rubio,0,aavail_basic,17
#
# -32,Cunningham,Philip,10/26/94,singapore,,singapore,m,25,Philip Cunningham,0,aavail_basic,22
#
# -33,Park,Landyn,10/07/91,Aliso Viejo,California,united_states,m,28,Landyn Park,0,aavail_premium,22
#
# -34,Ayers,Collins,02/05/82,singapore,,singapore,f,38,Collins Ayers,1,aavail_basic,21
#
# -35,Madden,Cecilia,12/31/77,singapore,,singapore,f,42,Cecilia Madden,1,aavail_unlimited,17
#
# -36,Valdez,Bella,04/05/86,singapore,,singapore,f,33,Bella Valdez,0,aavail_unlimited,11
#
# -37,Cardenas,Ishaan,11/11/81,Danbury,Connecticut,united_states,m,38,Ishaan Cardenas,1,aavail_premium,21
#
# -38,Grimes,Maddox,11/05/77,Inglewood,California,united_states,m,42,Maddox Grimes,0,aavail_unlimited,27
#
# -39,Santana,Salma,03/06/96,singapore,,singapore,f,24,Salma Santana,1,aavail_basic,19
#
# -40,Blackwell,Jaime,09/18/97,singapore,,singapore,m,22,Jaime Blackwell,1,aavail_premium,16
#
# -41,Davila,Cannon,01/15/98,Charlotte,North Carolina,united_states,m,22,Cannon Davila,0,aavail_premium,18
#
# -42,Hinton,Oliver,07/13/68,singapore,,singapore,m,51,Oliver Hinton,0,aavail_basic,18
#
# -43,Francis,Santiago,01/27/87,Huntsville,Texas,united_states,m,33,Santiago Francis,1,aavail_basic,23
#
# -44,Mayer,Remi,08/29/93,Peabody,Massachusetts,united_states,f,26,Remi Mayer,1,aavail_unlimited,21
#
# -45,Gutierrez,Kingsley,11/22/94,singapore,,singapore,m,25,Kingsley Gutierrez,0,aavail_unlimited,23
#
# -46,Shepard,Megan,12/01/97,singapore,,singapore,f,22,Megan Shepard,0,aavail_basic,8
#
# -47,Nava,Robert,04/12/76,Battle Creek,Michigan,united_states,m,43,Robert Nava,0,aavail_premium,22
#
# -48,Austin,Elijah,06/02/96,Phoenix,Arizona,united_states,m,23,Elijah Austin,0,aavail_unlimited,26
#
# -49,Reyes,Cash,09/03/95,Hesperia,California,united_states,m,24,Cash Reyes,0,aavail_premium,19
#
# -50,Nash,Ford,03/20/00,singapore,,singapore,m,19,Ford Nash,1,aavail_basic,16
#
# -51,Simpson,Isabella,01/05/94,Maricopa,Arizona,united_states,f,26,Isabella Simpson,0,aavail_basic,25
#
# -52,Curry,Lindsey,07/31/75,Alexandria,Louisiana,united_states,f,44,Lindsey Curry,1,aavail_basic,21
#
# -53,Klein,Chelsea,07/27/92,Mission Viejo,California,united_states,f,27,Chelsea Klein,0,aavail_basic,22
#
# -54,Bender,Kinslee,06/03/90,Norwalk,California,united_states,f,29,Kinslee Bender,1,aavail_basic,21
#
# -55,Hester,Harvey,08/17/94,Vacaville,California,united_states,m,25,Harvey Hester,0,aavail_premium,22
#
# -56,Sanford,Laila,01/06/02,Amarillo,Texas,united_states,f,18,Laila Sanford,0,aavail_premium,15
#
# -57,Houston,Fox,11/20/03,Bullhead City,Arizona,united_states,m,16,Fox Houston,0,aavail_premium,16
#
# -58,Ellis,Dorian,07/11/77,Boise City,Idaho,united_states,m,42,Dorian Ellis,0,aavail_basic,13
#
# -59,Barnes,Rafael,09/07/95,Fullerton,California,united_states,m,24,Rafael Barnes,0,aavail_unlimited,23
#
# -60,Norton,Aryan,02/07/00,Las Cruces,New Mexico,united_states,m,20,Aryan Norton,0,aavail_premium,9
#
# -61,Alvarado,Mohammad,08/28/96,Cleveland Heights,Ohio,united_states,m,23,Mohammad Alvarado,0,aavail_unlimited,21
#
# -62,Mccann,Raphael,07/28/74,Milton,Georgia,united_states,m,45,Raphael Mccann,0,aavail_basic,24
#
# -63,Lawrence,Izabella,08/02/92,Orlando,Florida,united_states,f,27,Izabella Lawrence,1,aavail_unlimited,21
#
# -64,Sierra,Bowen,06/27/75,Houston,Texas,united_states,m,44,Bowen Sierra,0,aavail_unlimited,20
#
# -65,Collier,Abram,07/20/99,Fort Myers,Florida,united_states,m,20,Abram Collier,1,aavail_premium,14
#
# -66,Villa,Howard,09/14/98,Johnson City,Tennessee,united_states,m,21,Howard Villa,1,aavail_premium,20
#
# -67,Webb,Harlan,09/05/96,North Miami Beach,Florida,united_states,m,23,Harlan Webb,0,aavail_unlimited,21
#
# -68,Sims,Samara,05/07/01,Cambridge,Massachusetts,united_states,f,18,Samara Sims,0,aavail_basic,15
#
# -69,Reilly,Dominick,04/13/99,singapore,,singapore,m,20,Dominick Reilly,1,aavail_premium,24
#
# -70,Chen,Amira,08/29/97,Brookhaven,Georgia,united_states,f,22,Amira Chen,0,aavail_premium,22
#
# -71,Mcpherson,River,04/06/98,Alameda,California,united_states,f,21,River Mcpherson,0,aavail_premium,24
#
# -72,Estrada,Maison,12/09/80,Montclair,California,united_states,m,39,Maison Estrada,0,aavail_basic,21
#
# -73,Grant,Mordechai,11/16/95,Shoreline,Washington,united_states,m,24,Mordechai Grant,0,aavail_premium,24
#
# -74,Peterson,Elianna,07/14/77,Newport Beach,California,united_states,f,42,Elianna Peterson,0,aavail_unlimited,23
#
# -75,Weaver,Genesis,02/12/90,Bell Gardens,California,united_states,f,30,Genesis Weaver,0,aavail_basic,20
#
# -76,Miranda,Mabel,09/29/97,Garden Grove,California,united_states,f,22,Mabel Miranda,0,aavail_unlimited,19
#
# -77,Dean,Kamilah,08/09/00,Collierville,Tennessee,united_states,f,19,Kamilah Dean,0,aavail_unlimited,21
#
# -78,Mosley,Alfredo,02/26/93,Marana,Arizona,united_states,m,27,Alfredo Mosley,0,aavail_unlimited,18
#
# -79,Barrett,Magnus,09/23/02,Palm Desert,California,united_states,m,17,Magnus Barrett,0,aavail_premium,22
#
# -80,Walter,Jedidiah,10/27/01,singapore,,singapore,m,18,Jedidiah Walter,0,aavail_basic,12
#
# -81,Avila,Ophelia,10/01/99,singapore,,singapore,f,20,Ophelia Avila,0,aavail_basic,23
#
# -82,Bradley,Lexi,10/26/98,Salina,Kansas,united_states,f,21,Lexi Bradley,0,aavail_premium,9
#
# -83,Walters,Jairo,08/22/78,Albuquerque,New Mexico,united_states,m,41,Jairo Walters,0,aavail_basic,18
#
# -84,Lowe,Javier,04/21/89,Lake Forest,California,united_states,m,30,Javier Lowe,0,aavail_unlimited,24
#
# -85,Fernandez,Gibson,02/18/99,Deerfield Beach,Florida,united_states,m,21,Gibson Fernandez,0,aavail_premium,23
#
# -86,Richard,Lane,02/17/97,Chula Vista,California,united_states,m,23,Lane Richard,1,aavail_premium,17
#
# -87,Alvarez,Briar,09/18/96,singapore,,singapore,f,23,Briar Alvarez,1,aavail_unlimited,9
#
# -88,Mora,Camille,11/30/94,Bountiful,Utah,united_states,f,25,Camille Mora,0,aavail_unlimited,23
#
# -89,Ashley,Melanie,10/26/97,Freeport,New York,united_states,f,22,Melanie Ashley,0,aavail_basic,24
#
# -90,Sharp,Carter,10/12/99,Sterling Heights,Michigan,united_states,m,20,Carter Sharp,1,aavail_unlimited,11
#
# -91,Terrell,Baker,01/26/95,singapore,,singapore,m,25,Baker Terrell,1,aavail_premium,15
#
# -92,Hammond,Callie,07/30/99,Puyallup,Washington,united_states,f,20,Callie Hammond,0,aavail_unlimited,21
#
# -93,Marsh,Amber,03/20/02,Las Vegas,Nevada,united_states,f,17,Amber Marsh,0,aavail_basic,26
#
# -94,Travis,Tristan,04/04/78,Frisco,Texas,united_states,m,41,Tristan Travis,0,aavail_unlimited,18
#
# -95,Melton,Chloe,04/24/81,singapore,,singapore,f,38,Chloe Melton,1,aavail_basic,19
#
# -96,Lewis,Dylan,06/05/93,Rochester,New York,united_states,m,26,Dylan Lewis,0,aavail_basic,19
#
# -97,Mcconnell,Ellis,10/19/83,singapore,,singapore,m,36,Ellis Mcconnell,1,aavail_premium,18
#
# -98,Lara,Nikolai,09/10/64,singapore,,singapore,m,55,Nikolai Lara,1,aavail_unlimited,11
#
# -99,Bell,Orion,07/29/94,Mankato,Minnesota,united_states,m,25,Orion Bell,0,aavail_premium,16
#
# -100,Roberson,Rylan,12/28/99,singapore,,singapore,m,20,Rylan Roberson,0,aavail_basic,22
#
# -101,Reid,Brysen,04/03/98,La Habra,California,united_states,m,21,Brysen Reid,0,aavail_unlimited,21
#
# -102,Blanchard,Myra,08/23/71,Asheville,North Carolina,united_states,f,48,Myra Blanchard,0,aavail_unlimited,18
#
# -103,Spence,Jordy,01/01/87,Corvallis,Oregon,united_states,m,33,Jordy Spence,0,aavail_unlimited,23
#
# -104,Copeland,Alijah,05/15/00,Downers Grove,Illinois,united_states,m,19,Alijah Copeland,0,aavail_basic,20
#
# -105,Woods,Keilani,11/25/96,Schenectady,New York,united_states,f,23,Keilani Woods,0,aavail_premium,25
#
# -106,Robles,Salvatore,03/23/92,Royal Oak,Michigan,united_states,m,27,Salvatore Robles,0,aavail_unlimited,18
#
# -107,Rosas,Saul,08/18/95,Spanish Fork,Utah,united_states,m,24,Saul Rosas,0,aavail_basic,17
#
# -108,Xiong,Scarlet,02/20/94,singapore,,singapore,f,26,Scarlet Xiong,1,aavail_unlimited,20
#
# -109,Fletcher,Malik,02/13/78,Shakopee,Minnesota,united_states,m,42,Malik Fletcher,0,aavail_unlimited,17
#
# -110,Goodwin,Parker,07/13/95,Hagerstown,Maryland,united_states,m,24,Parker Goodwin,0,aavail_unlimited,25
#
# -111,Lynch,Justice,03/13/70,Carlsbad,California,united_states,m,49,Justice Lynch,0,aavail_basic,22
#
# -112,Vega,Kian,12/01/88,Temecula,California,united_states,m,31,Kian Vega,0,aavail_unlimited,23
#
# -113,Mcgee,Elsie,12/27/79,singapore,,singapore,f,40,Elsie Mcgee,0,aavail_premium,19
#
# -114,Randolph,Christina,12/06/97,Perth Amboy,New Jersey,united_states,f,22,Christina Randolph,0,aavail_unlimited,21
#
# -115,Stevens,Myla,03/17/94,Peoria,Illinois,united_states,f,25,Myla Stevens,0,aavail_basic,24
#
# -116,Flynn,Lara,11/11/95,singapore,,singapore,f,24,Lara Flynn,1,aavail_unlimited,29
#
# -117,Khan,Anastasia,08/20/93,singapore,,singapore,f,26,Anastasia Khan,0,aavail_basic,21
#
# -118,Adkins,Nikolas,09/19/98,Bolingbrook,Illinois,united_states,m,21,Nikolas Adkins,1,aavail_premium,25
#
# -119,Patrick,Andrea,02/03/03,La Quinta,California,united_states,f,17,Andrea Patrick,0,aavail_unlimited,18
#
# -120,Blake,Tate,05/19/94,singapore,,singapore,m,25,Tate Blake,0,aavail_premium,19
#
# -121,Sherman,Sky,03/26/96,singapore,,singapore,f,23,Sky Sherman,1,aavail_basic,11
#
# -122,Palmer,Cara,02/07/99,Schaumburg,Illinois,united_states,f,21,Cara Palmer,0,aavail_unlimited,14
#
# -123,Hanson,Sutton,09/26/98,Columbus,Ohio,united_states,m,21,Sutton Hanson,0,aavail_premium,16
#
# -124,Contreras,Jaxxon,06/30/78,singapore,,singapore,m,41,Jaxxon Contreras,1,aavail_premium,16
#
# -125,Decker,Graysen,11/18/87,Richmond,Virginia,united_states,m,32,Graysen Decker,0,aavail_premium,12
#
# -126,Espinosa,Callum,01/27/90,Shreveport,Louisiana,united_states,m,30,Callum Espinosa,0,aavail_premium,19
#
# -127,Orozco,Lyla,12/21/99,singapore,,singapore,f,20,Lyla Orozco,0,aavail_premium,19
#
# -128,Atkins,Lyra,09/29/00,Daytona Beach,Florida,united_states,f,19,Lyra Atkins,1,aavail_premium,26
#
# -129,Pace,William,07/15/97,singapore,,singapore,m,22,William Pace,0,aavail_basic,2
#
# -130,Maxwell,Raymond,03/24/93,Richardson,Texas,united_states,m,26,Raymond Maxwell,0,aavail_unlimited,17
#
# -131,Long,Everett,07/12/77,Newark,Ohio,united_states,m,42,Everett Long,0,aavail_basic,23
#
# -132,Bowman,Hassan,07/23/90,Greensboro,North Carolina,united_states,m,29,Hassan Bowman,1,aavail_unlimited,18
#
# -133,Salgado,Leonel,07/16/95,Twin Falls,Idaho,united_states,m,24,Leonel Salgado,0,aavail_basic,20
#
# -134,Carson,Grey,05/09/01,singapore,,singapore,m,18,Grey Carson,1,aavail_premium,15
#
# -135,Hart,Hope,01/20/92,Frederick,Maryland,united_states,f,28,Hope Hart,0,aavail_premium,22
#
# -136,Trevino,Randy,02/07/98,New York,New York,united_states,m,22,Randy Trevino,0,aavail_premium,23
#
# -137,Luna,Lee,09/11/00,singapore,,singapore,m,19,Lee Luna,0,aavail_basic,15
#
# -138,Villanueva,Ariadne,05/27/00,Everett,Massachusetts,united_states,f,19,Ariadne Villanueva,0,aavail_unlimited,12
#
# -139,Washington,Cairo,03/25/94,Yorba Linda,California,united_states,m,25,Cairo Washington,0,aavail_unlimited,13
#
# -140,Frazier,Mira,02/20/96,singapore,,singapore,f,24,Mira Frazier,0,aavail_unlimited,13
#
# -141,Franklin,Rosa,08/27/96,singapore,,singapore,f,23,Rosa Franklin,1,aavail_unlimited,13
#
# -142,Carrillo,Ismael,08/20/93,Winter Haven,Florida,united_states,m,26,Ismael Carrillo,0,aavail_unlimited,25
#
# -143,Noble,Jaxx,04/13/72,Clearwater,Florida,united_states,m,47,Jaxx Noble,0,aavail_basic,19
#
# -144,Miller,London,04/26/99,Greenville,South Carolina,united_states,m,20,London Miller,0,aavail_basic,20
#
# -145,Bailey,Oakley,12/18/93,Pasadena,Texas,united_states,m,26,Oakley Bailey,0,aavail_premium,16
#
# -146,Jefferson,Kyng,10/26/99,San Marcos,California,united_states,m,20,Kyng Jefferson,0,aavail_premium,24
#
# -147,Romero,Eliana,04/23/91,Upland,California,united_states,f,28,Eliana Romero,0,aavail_basic,18
#
# -148,Conner,Caiden,03/25/95,Oakley,California,united_states,m,24,Caiden Conner,0,aavail_basic,19
#
# -149,Graham,Cristian,04/14/00,Malden,Massachusetts,united_states,m,19,Cristian Graham,1,aavail_basic,23
#
# -150,Johnson,Wade,03/21/70,singapore,,singapore,m,49,Wade Johnson,1,aavail_unlimited,9
#
# -151,Patel,Aubrie,09/22/03,singapore,,singapore,f,16,Aubrie Patel,0,aavail_premium,7
#
# -152,Vargas,Kamdyn,09/10/95,Bismarck,North Dakota,united_states,m,24,Kamdyn Vargas,0,aavail_premium,23
#
# -153,Everett,Roberto,05/25/98,Baldwin Park,California,united_states,m,21,Roberto Everett,0,aavail_unlimited,20
#
# -154,Gould,Eduardo,05/18/80,Sioux Falls,South Dakota,united_states,m,39,Eduardo Gould,0,aavail_unlimited,20
#
# -155,Mullen,Kailyn,06/24/97,singapore,,singapore,f,22,Kailyn Mullen,0,aavail_basic,15
#
# -156,Hodge,Dillon,06/16/95,Wichita,Kansas,united_states,m,24,Dillon Hodge,0,aavail_premium,20
#
# -157,Mullins,Arianna,02/22/94,Cheyenne,Wyoming,united_states,f,26,Arianna Mullins,0,aavail_premium,22
#
# -158,Blackburn,Vanessa,03/12/93,Mansfield,Ohio,united_states,f,26,Vanessa Blackburn,0,aavail_premium,22
#
# -159,Skinner,August,05/28/01,Waukegan,Illinois,united_states,m,18,August Skinner,0,aavail_unlimited,23
#
# -160,Lim,Willa,06/08/93,singapore,,singapore,f,26,Willa Lim,0,aavail_basic,20
#
# -161,Richardson,Rogelio,11/26/99,Norwalk,Connecticut,united_states,m,20,Rogelio Richardson,0,aavail_premium,21
#
# -162,Oneal,Delilah,08/13/04,DeKalb,Illinois,united_states,f,15,Delilah Oneal,1,aavail_unlimited,18
#
# -163,Peck,Savannah,12/06/01,Union City,California,united_states,f,18,Savannah Peck,0,aavail_basic,21
#
# -164,Reynolds,Alejandro,04/09/96,Springfield,Illinois,united_states,m,23,Alejandro Reynolds,0,aavail_basic,23
#
# -165,Solomon,Maxwell,03/08/64,Casa Grande,Arizona,united_states,m,56,Maxwell Solomon,0,aavail_basic,13
#
# -166,Glass,Karina,08/23/00,Kingsport,Tennessee,united_states,f,19,Karina Glass,1,aavail_unlimited,20
#
# -167,Berg,Tommy,01/20/98,Yakima,Washington,united_states,m,22,Tommy Berg,1,aavail_unlimited,15
#
# -168,Morrison,Adrien,10/27/96,Smyrna,Georgia,united_states,m,23,Adrien Morrison,0,aavail_basic,23
#
# -169,Cortez,Julian,03/25/98,Chicago,Illinois,united_states,m,21,Julian Cortez,1,aavail_premium,21
#
# -170,Ellison,Levi,07/01/91,singapore,,singapore,m,28,Levi Ellison,1,aavail_premium,8
#
# -171,Mcdowell,Abby,07/10/98,singapore,,singapore,f,21,Abby Mcdowell,1,aavail_premium,21
#
# -172,Clayton,Axel,12/03/01,Rogers,Arkansas,united_states,m,18,Axel Clayton,0,aavail_premium,20
#
# -173,Leonard,Miller,11/19/97,Anaheim,California,united_states,m,22,Miller Leonard,1,aavail_premium,21
#
# -174,Merritt,Gus,10/30/03,singapore,,singapore,m,16,Gus Merritt,0,aavail_unlimited,14
#
# -175,Paul,Brooke,01/03/00,singapore,,singapore,f,20,Brooke Paul,0,aavail_unlimited,11
#
# -176,Calhoun,Sebastian,01/28/01,Miami Gardens,Florida,united_states,m,19,Sebastian Calhoun,1,aavail_premium,22
#
# -177,Nelson,Clementine,04/20/98,Grapevine,Texas,united_states,f,21,Clementine Nelson,0,aavail_premium,20
#
# -178,Blevins,Kye,04/09/77,Clarksville,Tennessee,united_states,m,42,Kye Blevins,0,aavail_basic,24
#
# -179,Chandler,Katherine,08/14/98,Vancouver,Washington,united_states,f,21,Katherine Chandler,0,aavail_basic,16
#
# -180,Kennedy,Dane,05/22/87,Commerce City,Colorado,united_states,m,32,Dane Kennedy,0,aavail_basic,19
#
# -181,Kent,Donovan,02/03/79,singapore,,singapore,m,41,Donovan Kent,1,aavail_unlimited,22
#
# -182,Beasley,Garrett,10/18/82,Euless,Texas,united_states,m,37,Garrett Beasley,0,aavail_unlimited,25
#
# -183,Mcintosh,Aileen,02/24/94,El Cajon,California,united_states,f,26,Aileen Mcintosh,0,aavail_basic,19
#
# -184,Anthony,Legacy,12/17/92,Waterloo,Iowa,united_states,f,27,Legacy Anthony,0,aavail_basic,21
#
# -185,Jacobson,Walker,01/07/77,singapore,,singapore,m,43,Walker Jacobson,1,aavail_premium,13
#
# -186,Schultz,Valery,03/11/00,Cerritos,California,united_states,f,19,Valery Schultz,0,aavail_unlimited,21
#
# -187,Gallagher,Vivian,10/08/91,Pomona,California,united_states,f,28,Vivian Gallagher,0,aavail_unlimited,22
#
# -188,Gilmore,Archer,08/26/80,Clifton,New Jersey,united_states,m,39,Archer Gilmore,0,aavail_basic,21
#
# -189,Woodward,Jaxton,01/10/85,Westminster,California,united_states,m,35,Jaxton Woodward,0,aavail_premium,24
#
# -190,Floyd,Jett,05/28/99,singapore,,singapore,m,20,Jett Floyd,1,aavail_basic,20
#
# -191,Stein,Leland,02/06/97,Goodyear,Arizona,united_states,m,23,Leland Stein,0,aavail_premium,21
#
# -192,Wade,Khloe,07/09/95,Mesa,Arizona,united_states,f,24,Khloe Wade,0,aavail_basic,24
#
# -193,Patton,Charlotte,02/03/85,singapore,,singapore,f,35,Charlotte Patton,0,aavail_premium,15
#
# -194,Morales,Sabrina,03/29/67,Lexington-Fayette,Kentucky,united_states,f,52,Sabrina Morales,0,aavail_premium,21
#
# -195,Arias,Wells,10/19/90,singapore,,singapore,m,29,Wells Arias,1,aavail_premium,10
#
# -196,Hurley,Prince,08/11/99,Santa Clarita,California,united_states,m,20,Prince Hurley,0,aavail_basic,18
#
# -197,Cain,Marie,10/23/76,singapore,,singapore,f,43,Marie Cain,0,aavail_unlimited,24
#
# -198,Davenport,Ariah,09/01/02,North Richland Hills,Texas,united_states,f,17,Ariah Davenport,1,aavail_unlimited,24
#
# -199,Delacruz,Jewel,12/07/93,Cleveland,Ohio,united_states,f,26,Jewel Delacruz,0,aavail_premium,25
#
# -200,Herman,Ezra,07/28/89,Lorain,Ohio,united_states,f,30,Ezra Herman,1,aavail_unlimited,17
#
# -201,Bush,Tinley,01/10/01,North Charleston,South Carolina,united_states,f,19,Tinley Bush,0,aavail_unlimited,24
#
# -202,Reed,Malcolm,11/28/98,singapore,,singapore,m,21,Malcolm Reed,1,aavail_unlimited,19
#
# -203,Gilbert,Byron,06/18/00,Kenner,Louisiana,united_states,m,19,Byron Gilbert,0,aavail_unlimited,22
#
# -204,Wheeler,Simone,03/21/98,Norfolk,Virginia,united_states,f,21,Simone Wheeler,1,aavail_premium,20
#
# -205,Bruce,Alia,12/12/76,Pocatello,Idaho,united_states,f,43,Alia Bruce,0,aavail_unlimited,25
#
# -206,Conrad,Lian,12/02/00,singapore,,singapore,m,19,Lian Conrad,1,aavail_basic,23
#
# -207,Gillespie,Augustine,04/24/80,Flower Mound,Texas,united_states,m,39,Augustine Gillespie,1,aavail_basic,9
#
# -208,Beck,Peyton,01/23/96,Waukesha,Wisconsin,united_states,f,24,Peyton Beck,0,aavail_basic,21
#
# -209,Valencia,Omar,06/30/97,Summerville,South Carolina,united_states,m,22,Omar Valencia,1,aavail_basic,25
#
# -210,Freeman,Micah,07/27/99,Hallandale Beach,Florida,united_states,m,20,Micah Freeman,1,aavail_premium,25
#
# -211,Marin,Gunner,01/04/95,Bartlett,Illinois,united_states,m,25,Gunner Marin,0,aavail_premium,23
#
# -212,Yu,Annabel,09/19/96,singapore,,singapore,f,23,Annabel Yu,1,aavail_premium,19
#
# -213,Holloway,Elisa,12/27/03,Downey,California,united_states,f,16,Elisa Holloway,0,aavail_basic,20
#
# -214,Dixon,Quinton,03/23/94,singapore,,singapore,m,25,Quinton Dixon,1,aavail_basic,22
#
# -215,Bond,Henley,11/12/96,Victoria,Texas,united_states,f,23,Henley Bond,0,aavail_basic,20
#
# -216,Rowe,Braden,06/23/79,singapore,,singapore,m,40,Braden Rowe,1,aavail_basic,21
#
# -217,Knox,Graham,12/04/93,singapore,,singapore,m,26,Graham Knox,0,aavail_unlimited,18
#
# -218,Quintero,Malia,09/04/74,Santa Clara,California,united_states,f,45,Malia Quintero,0,aavail_premium,18
#
# -219,Hines,Celine,10/04/97,Logan,Utah,united_states,f,22,Celine Hines,0,aavail_basic,8
#
# -220,Whitehead,Wren,07/12/99,singapore,,singapore,f,20,Wren Whitehead,1,aavail_basic,21
#
# -221,Higgins,Avalynn,03/08/98,Pueblo,Colorado,united_states,f,22,Avalynn Higgins,0,aavail_basic,24
#
# -222,Erickson,Colin,11/15/95,Birmingham,Alabama,united_states,m,24,Colin Erickson,0,aavail_basic,22
#
# -223,Gomez,Jamari,03/13/99,Colton,California,united_states,m,20,Jamari Gomez,0,aavail_unlimited,13
#
# -224,Riley,Misael,06/10/72,Manchester,New Hampshire,united_states,m,47,Misael Riley,0,aavail_basic,19
#
# -225,Soto,Merrick,03/02/84,Rockville,Maryland,united_states,m,36,Merrick Soto,0,aavail_basic,13
#
# -226,Vincent,Ryland,12/01/98,singapore,,singapore,m,21,Ryland Vincent,1,aavail_premium,7
#
# -227,Buchanan,Maia,08/30/98,singapore,,singapore,f,21,Maia Buchanan,1,aavail_premium,17
#
# -228,Whitney,Noe,12/29/79,Elkhart,Indiana,united_states,m,40,Noe Whitney,0,aavail_premium,22
#
# -229,Mclean,Dakota,12/20/00,Kyle,Texas,united_states,f,19,Dakota Mclean,0,aavail_unlimited,14
#
# -230,Michael,Della,05/02/82,Casper,Wyoming,united_states,f,37,Della Michael,1,aavail_unlimited,20
#
# -231,Tucker,Kaylin,05/15/75,Santa Ana,California,united_states,f,44,Kaylin Tucker,0,aavail_basic,20
#
# -232,Bryan,Xander,10/24/80,singapore,,singapore,m,39,Xander Bryan,1,aavail_unlimited,11
#
# -233,Fox,Desmond,06/17/99,singapore,,singapore,m,20,Desmond Fox,1,aavail_basic,22
#
# -234,Mcclain,Greyson,10/01/96,Hurst,Texas,united_states,m,23,Greyson Mcclain,0,aavail_unlimited,23
#
# -235,Lam,Dash,05/14/93,Tyler,Texas,united_states,m,26,Dash Lam,0,aavail_premium,23
#
# -236,Watts,Brooklynn,08/29/96,Apple Valley,California,united_states,f,23,Brooklynn Watts,0,aavail_basic,22
#
# -237,Charles,Alexander,04/29/79,singapore,,singapore,m,40,Alexander Charles,0,aavail_premium,10
#
# -238,Donaldson,Jeremy,06/13/97,Macon-Bibb County,Georgia,united_states,m,22,Jeremy Donaldson,0,aavail_basic,21
#
# -239,Saunders,Emory,03/28/99,Sheboygan,Wisconsin,united_states,f,20,Emory Saunders,0,aavail_premium,20
#
# -240,Jarvis,Maurice,09/30/81,Haverhill,Massachusetts,united_states,m,38,Maurice Jarvis,0,aavail_basic,24
#
# -241,Stephenson,Mariam,11/28/80,San Mateo,California,united_states,f,39,Mariam Stephenson,0,aavail_basic,20
#
# -242,Rodriguez,Isabel,09/01/69,Melbourne,Florida,united_states,f,50,Isabel Rodriguez,0,aavail_unlimited,24
#
# -243,Hood,Zainab,10/19/65,singapore,,singapore,f,54,Zainab Hood,1,aavail_premium,16
#
# -244,Fitzpatrick,Camden,08/20/94,Moline,Illinois,united_states,m,25,Camden Fitzpatrick,1,aavail_basic,24
#
# -245,Young,Joe,04/17/96,St. George,Utah,united_states,m,23,Joe Young,1,aavail_unlimited,24
#
# -246,Castaneda,Ariyah,11/26/77,Florissant,Missouri,united_states,f,42,Ariyah Castaneda,0,aavail_premium,22
#
# -247,Dodson,Harold,11/16/99,singapore,,singapore,m,20,Harold Dodson,1,aavail_unlimited,15
#
# -248,Kirk,Saoirse,07/02/94,singapore,,singapore,f,25,Saoirse Kirk,1,aavail_unlimited,21
#
# -249,Haynes,Kaliyah,01/27/96,Carson City,Nevada,united_states,f,24,Kaliyah Haynes,0,aavail_unlimited,19
#
# -250,Mahoney,Giselle,04/07/99,Lincoln,California,united_states,f,20,Giselle Mahoney,0,aavail_unlimited,22
#
# -251,Obrien,Landry,02/23/80,singapore,,singapore,m,40,Landry Obrien,0,aavail_basic,15
#
# -252,Chan,Vivaan,09/01/97,singapore,,singapore,m,22,Vivaan Chan,0,aavail_unlimited,6
#
# -253,Hawkins,Treasure,11/05/98,Lawton,Oklahoma,united_states,f,21,Treasure Hawkins,0,aavail_premium,7
#
# -254,Lin,Valentin,09/10/89,Buckeye,Arizona,united_states,m,30,Valentin Lin,0,aavail_basic,22
#
# -255,Randall,Andre,02/10/96,Marlborough,Massachusetts,united_states,m,24,Andre Randall,0,aavail_basic,16
#
# -256,Armstrong,Hayes,02/27/96,singapore,,singapore,m,24,Hayes Armstrong,1,aavail_basic,11
#
# -257,Booth,Hadley,08/26/96,Hamilton,Ohio,united_states,f,23,Hadley Booth,0,aavail_basic,20
#
# -258,Thomas,Kalani,04/04/89,Santa Barbara,California,united_states,f,30,Kalani Thomas,0,aavail_unlimited,22
#
# -259,Dalton,Mateo,03/24/93,singapore,,singapore,m,26,Mateo Dalton,1,aavail_unlimited,14
#
# -260,Maddox,Dominik,11/11/97,singapore,,singapore,m,22,Dominik Maddox,1,aavail_premium,11
#
# -261,Parsons,Luna,08/14/99,Wentzville,Missouri,united_states,f,20,Luna Parsons,0,aavail_premium,22
#
# -262,Schmidt,Liana,06/26/94,Pembroke Pines,Florida,united_states,f,25,Liana Schmidt,0,aavail_premium,21
#
# -263,Swanson,Mason,04/16/98,singapore,,singapore,m,21,Mason Swanson,0,aavail_basic,18
#
# -264,Cano,Luis,09/19/84,Merced,California,united_states,m,35,Luis Cano,1,aavail_premium,7
#
# -265,Lloyd,Linda,05/06/00,Strongsville,Ohio,united_states,f,19,Linda Lloyd,0,aavail_basic,19
#
# -266,Stephens,Jamie,08/10/80,Walnut Creek,California,united_states,f,39,Jamie Stephens,0,aavail_basic,21
#
# -267,Sexton,Delaney,02/28/01,singapore,,singapore,f,19,Delaney Sexton,1,aavail_basic,19
#
# -268,Hobbs,Keily,02/28/92,San Ramon,California,united_states,f,28,Keily Hobbs,1,aavail_basic,18
#
# -269,Ortega,Hudson,04/03/97,Concord,North Carolina,united_states,m,22,Hudson Ortega,0,aavail_premium,24
#
# -270,Nguyen,Taylor,10/10/83,Little Rock,Arkansas,united_states,m,36,Taylor Nguyen,0,aavail_premium,20
#
# -271,Salazar,Chanel,02/04/00,Redondo Beach,California,united_states,f,20,Chanel Salazar,0,aavail_unlimited,21
#
# -272,Gallegos,Michelle,12/26/98,New Britain,Connecticut,united_states,f,21,Michelle Gallegos,0,aavail_premium,17
#
# -273,Duncan,Bonnie,12/21/95,Bethlehem,Pennsylvania,united_states,f,24,Bonnie Duncan,0,aavail_unlimited,22
#
# -274,James,Laurel,08/08/98,East Orange,New Jersey,united_states,f,21,Laurel James,1,aavail_premium,24
#
# -275,Esquivel,Dariel,01/03/02,Edmond,Oklahoma,united_states,m,18,Dariel Esquivel,0,aavail_basic,22
#
# -276,Munoz,Tony,06/30/96,Council Bluffs,Iowa,united_states,m,23,Tony Munoz,1,aavail_unlimited,17
#
# -277,Valentine,Kallie,12/21/93,Middletown,Connecticut,united_states,f,26,Kallie Valentine,0,aavail_unlimited,21
#
# -278,Leblanc,Avah,07/03/94,Lake Charles,Louisiana,united_states,f,25,Avah Leblanc,0,aavail_premium,11
#
# -279,Figueroa,Remington,09/10/99,Hollywood,Florida,united_states,f,20,Remington Figueroa,1,aavail_unlimited,23
#
# -280,Maldonado,Zaniyah,12/29/83,Corona,California,united_states,f,36,Zaniyah Maldonado,0,aavail_unlimited,18
#
# -281,Garner,Arlette,03/04/70,Winston-Salem,North Carolina,united_states,f,50,Arlette Garner,0,aavail_unlimited,21
#
# -282,Fields,Mohamed,09/22/79,Manteca,California,united_states,m,40,Mohamed Fields,0,aavail_premium,23
#
# -283,Dominguez,Kash,12/10/93,Richland,Washington,united_states,m,26,Kash Dominguez,0,aavail_premium,23
#
# -284,Rasmussen,Jace,02/28/96,singapore,,singapore,m,24,Jace Rasmussen,1,aavail_basic,17
#
# -285,Curtis,Derrick,08/14/93,Wilmington,Delaware,united_states,m,26,Derrick Curtis,1,aavail_basic,23
#
# -286,Juarez,Tucker,10/10/95,Ames,Iowa,united_states,m,24,Tucker Juarez,0,aavail_basic,25
#
# -287,Horton,Jayceon,08/15/02,Schertz,Texas,united_states,m,17,Jayceon Horton,0,aavail_basic,21
#
# -288,Rowland,Jon,01/04/93,Los Angeles,California,united_states,m,27,Jon Rowland,0,aavail_unlimited,20
#
# -289,Brown,Jesse,05/27/97,San Angelo,Texas,united_states,m,22,Jesse Brown,0,aavail_premium,22
#
# -290,Little,Curtis,02/09/96,Missoula,Montana,united_states,m,24,Curtis Little,1,aavail_basic,22
#
# -291,White,Jaiden,12/14/78,Cape Girardeau,Missouri,united_states,m,41,Jaiden White,0,aavail_unlimited,17
#
# -292,Duffy,Aden,01/12/02,Livermore,California,united_states,m,18,Aden Duffy,0,aavail_premium,17
#
# -293,Nichols,Eve,02/01/96,Racine,Wisconsin,united_states,f,24,Eve Nichols,0,aavail_basic,12
#
# -294,Stafford,Justin,11/07/94,Lake Oswego,Oregon,united_states,m,25,Justin Stafford,0,aavail_unlimited,24
#
# -295,Weber,Bishop,02/20/91,Hendersonville,Tennessee,united_states,m,29,Bishop Weber,0,aavail_unlimited,20
#
# -296,Phan,Jeffrey,07/24/93,South San Francisco,California,united_states,m,26,Jeffrey Phan,0,aavail_premium,24
#
# -297,Brock,Caroline,01/25/84,El Centro,California,united_states,f,36,Caroline Brock,0,aavail_unlimited,24
#
# -298,Espinoza,Ariel,01/09/73,singapore,,singapore,m,47,Ariel Espinoza,0,aavail_unlimited,12
#
# -299,Guerra,Jolie,07/04/95,San Jose,California,united_states,f,24,Jolie Guerra,0,aavail_unlimited,24
#
# -300,Perry,Israel,11/05/80,Seattle,Washington,united_states,m,39,Israel Perry,0,aavail_premium,25
#
# -301,Fisher,Jamie,12/31/82,singapore,,singapore,m,37,Jamie Fisher,0,aavail_premium,21
#
# -302,Spears,Joziah,12/09/88,singapore,,singapore,m,31,Joziah Spears,0,aavail_basic,20
#
# -303,Stevenson,Bowie,11/17/79,Waco,Texas,united_states,m,40,Bowie Stevenson,0,aavail_unlimited,24
#
# -304,Quintana,Leila,08/30/02,singapore,,singapore,f,17,Leila Quintana,1,aavail_basic,20
#
# -305,Keller,Maleah,10/23/97,singapore,,singapore,f,22,Maleah Keller,1,aavail_unlimited,20
#
# -306,Robbins,Alma,03/10/99,Peoria,Arizona,united_states,f,21,Alma Robbins,1,aavail_unlimited,23
#
# -307,Daniel,Kalel,10/11/96,Grand Island,Nebraska,united_states,m,23,Kalel Daniel,0,aavail_premium,24
#
# -308,Underwood,Otto,08/06/82,Coral Gables,Florida,united_states,m,37,Otto Underwood,0,aavail_unlimited,21
#
# -309,Garrett,Taliyah,11/03/01,Lawrence,Kansas,united_states,f,18,Taliyah Garrett,0,aavail_basic,21
#
# -310,Tran,Luca,05/03/69,Springfield,Massachusetts,united_states,m,50,Luca Tran,0,aavail_unlimited,18
#
# -311,Medina,Marcel,09/12/68,singapore,,singapore,m,51,Marcel Medina,1,aavail_premium,22
#
# -312,Flores,Nova,11/03/86,singapore,,singapore,m,33,Nova Flores,1,aavail_premium,10
#
# -313,Crosby,John,05/09/86,Burlington,North Carolina,united_states,m,33,John Crosby,0,aavail_premium,20
#
# -314,Montes,Reign,12/30/98,singapore,,singapore,f,21,Reign Montes,0,aavail_unlimited,12
#
# -315,Kramer,Rosie,11/19/99,Cary,North Carolina,united_states,f,20,Rosie Kramer,0,aavail_basic,10
#
# -316,Maynard,Kamryn,08/04/99,singapore,,singapore,f,20,Kamryn Maynard,0,aavail_premium,16
#
# -317,Levy,Alaric,12/22/99,Lincoln,Nebraska,united_states,m,20,Alaric Levy,0,aavail_basic,21
#
# -318,Camacho,Ruben,07/16/97,singapore,,singapore,m,22,Ruben Camacho,0,aavail_basic,22
#
# -319,Ramos,Landon,10/08/96,Stockton,California,united_states,m,23,Landon Ramos,0,aavail_premium,18
#
# -320,Moran,Jonah,12/08/81,Surprise,Arizona,united_states,m,38,Jonah Moran,1,aavail_premium,25
#
# -321,Massey,Alex,05/20/04,Rialto,California,united_states,m,15,Alex Massey,0,aavail_basic,23
#
# -322,Schneider,Amy,05/27/04,singapore,,singapore,f,15,Amy Schneider,0,aavail_basic,19
#
# -323,York,Rory,08/07/98,Warren,Ohio,united_states,f,21,Rory York,0,aavail_basic,21
#
# -324,Lawson,Benjamin,06/26/98,San Bernardino,California,united_states,m,21,Benjamin Lawson,0,aavail_unlimited,23
#
# -325,Dunn,Nora,08/06/96,Denver,Colorado,united_states,f,23,Nora Dunn,0,aavail_premium,18
#
# -326,Gross,Arielle,02/04/85,Columbus,Georgia,united_states,f,35,Arielle Gross,0,aavail_basic,18
#
# -327,Delgado,Finn,10/20/99,Buffalo,New York,united_states,m,20,Finn Delgado,1,aavail_basic,22
#
# -328,Rios,Jillian,12/02/78,Millcreek,Utah,united_states,f,41,Jillian Rios,0,aavail_unlimited,22
#
# -329,Mckinney,Vincenzo,08/31/97,Durham,North Carolina,united_states,m,22,Vincenzo Mckinney,0,aavail_unlimited,27
#
# -330,Ryan,Dax,11/22/81,Marion,Iowa,united_states,m,38,Dax Ryan,0,aavail_premium,22
#
# -331,Sullivan,Keanu,12/24/97,Murfreesboro,Tennessee,united_states,m,22,Keanu Sullivan,0,aavail_unlimited,23
#
# -332,Green,Emilee,03/22/99,Louisville/Jefferson County,Kentucky,united_states,f,20,Emilee Green,0,aavail_basic,23
#
# -333,Vazquez,Caden,08/19/94,Nampa,Idaho,united_states,m,25,Caden Vazquez,0,aavail_basic,23
#
# -334,Navarro,Esteban,07/13/77,West Valley City,Utah,united_states,m,42,Esteban Navarro,1,aavail_premium,24
#
# -335,Harvey,Titus,08/06/96,Mansfield,Texas,united_states,m,23,Titus Harvey,0,aavail_basic,19
#
# -336,Schwartz,Rhys,03/03/95,singapore,,singapore,m,25,Rhys Schwartz,0,aavail_basic,21
#
# -337,Moss,Helen,07/02/73,singapore,,singapore,f,46,Helen Moss,0,aavail_basic,20
#
# -338,Edwards,Talia,06/04/85,Biloxi,Mississippi,united_states,f,34,Talia Edwards,0,aavail_premium,22
#
# -339,Orr,Dawson,06/20/97,singapore,,singapore,m,22,Dawson Orr,1,aavail_basic,22
#
# -340,Bentley,Yosef,01/22/74,singapore,,singapore,m,46,Yosef Bentley,0,aavail_basic,12
#
# -341,Barnett,Cesar,12/03/91,singapore,,singapore,m,28,Cesar Barnett,0,aavail_unlimited,16
#
# -342,Trejo,Atlas,05/27/95,singapore,,singapore,m,24,Atlas Trejo,1,aavail_basic,9
#
# -343,Reese,Roger,06/02/98,Loveland,Colorado,united_states,m,21,Roger Reese,0,aavail_basic,6
#
# -344,Warren,Frank,05/20/83,Kokomo,Indiana,united_states,m,36,Frank Warren,0,aavail_basic,23
#
# -345,Frederick,Edwin,10/19/66,Culver City,California,united_states,m,53,Edwin Frederick,0,aavail_premium,24
#
# -346,Pacheco,Ana,09/21/95,Midland,Michigan,united_states,f,24,Ana Pacheco,1,aavail_unlimited,20
#
# -347,Bradford,Noemi,05/29/02,singapore,,singapore,f,17,Noemi Bradford,1,aavail_unlimited,23
#
# -348,Giles,Duke,09/20/97,Lake Elsinore,California,united_states,m,22,Duke Giles,0,aavail_premium,24
#
# -349,Santos,Kaiser,06/04/69,Eden Prairie,Minnesota,united_states,m,50,Kaiser Santos,1,aavail_premium,21
#
# -350,Norris,Carly,12/30/80,Jupiter,Florida,united_states,f,39,Carly Norris,1,aavail_basic,24
#
# -351,Flowers,Cedric,02/26/96,Athens-Clarke County,Georgia,united_states,m,24,Cedric Flowers,0,aavail_unlimited,22
#
# -352,Odonnell,Emilia,02/01/86,Hackensack,New Jersey,united_states,f,34,Emilia Odonnell,0,aavail_unlimited,21
#
# -353,Clements,Iliana,07/21/86,Sacramento,California,united_states,f,33,Iliana Clements,0,aavail_basic,13
#
# -354,Lowery,Albert,04/06/97,Idaho Falls,Idaho,united_states,m,22,Albert Lowery,0,aavail_premium,18
#
# -355,Mccarty,Casen,06/21/98,New Bedford,Massachusetts,united_states,m,21,Casen Mccarty,1,aavail_unlimited,25
#
# -356,Moses,Emmalyn,09/14/00,Taylor,Michigan,united_states,f,19,Emmalyn Moses,1,aavail_basic,19
#
# -357,Lu,Miguel,03/26/99,Methuen,Massachusetts,united_states,m,20,Miguel Lu,0,aavail_basic,22
#
# -358,Mcbride,Jude,09/09/97,singapore,,singapore,m,22,Jude Mcbride,1,aavail_premium,4
#
# -359,Durham,Irene,08/28/00,Mount Vernon,New York,united_states,f,19,Irene Durham,0,aavail_unlimited,25
#
# -360,Mcguire,Markus,11/19/74,Hialeah,Florida,united_states,m,45,Markus Mcguire,0,aavail_unlimited,17
#
# -361,Serrano,Fernando,08/10/92,San Clemente,California,united_states,m,27,Fernando Serrano,0,aavail_premium,18
#
# -362,Moyer,Rowan,03/28/05,Cedar Rapids,Iowa,united_states,f,14,Rowan Moyer,0,aavail_basic,3
#
# -363,Herrera,Isaiah,02/18/98,North Lauderdale,Florida,united_states,m,22,Isaiah Herrera,0,aavail_premium,17
#
# -364,King,Trace,08/21/97,Delano,California,united_states,m,22,Trace King,0,aavail_basic,22
#
# -365,Hurst,Angel,07/10/95,Belleville,Illinois,united_states,f,24,Angel Hurst,0,aavail_unlimited,17
#
# -366,Palacios,Enrique,05/22/00,singapore,,singapore,m,19,Enrique Palacios,1,aavail_basic,8
#
# -367,Dudley,Lennox,11/07/94,singapore,,singapore,f,25,Lennox Dudley,0,aavail_basic,18
#
# -368,Lester,Louisa,10/16/01,Gulfport,Mississippi,united_states,f,18,Louisa Lester,0,aavail_premium,20
#
# -369,Mayo,Bryson,07/27/99,DeSoto,Texas,united_states,m,20,Bryson Mayo,0,aavail_unlimited,26
#
# -370,Tanner,Charles,03/29/95,singapore,,singapore,m,24,Charles Tanner,0,aavail_premium,20
#
# -371,Monroe,Camilo,01/26/80,singapore,,singapore,m,40,Camilo Monroe,1,aavail_unlimited,13
#
# -372,Farley,Mohammed,07/27/94,New Orleans,Louisiana,united_states,m,25,Mohammed Farley,0,aavail_basic,22
#
# -373,Hail,Tristian,03/06/01,Mobile,Alabama,united_states,m,19,Tristian Hail,0,aavail_premium,20
#
# -374,Hardin,Aliya,06/14/73,Albany,New York,united_states,f,46,Aliya Hardin,1,aavail_premium,22
#
# -375,Dickson,Daniel,05/13/89,Yucaipa,California,united_states,m,30,Daniel Dickson,0,aavail_basic,8
#
# -376,Leacock,Julius,05/22/00,Yuma,Arizona,united_states,m,19,Julius Leacock,0,aavail_unlimited,20
#
# -377,Velazquez,Zariyah,12/23/66,Fort Lauderdale,Florida,united_states,f,53,Zariyah Velazquez,0,aavail_unlimited,17
#
# -378,Magana,Lorenzo,04/14/01,La Mirada,California,united_states,m,18,Lorenzo Magana,0,aavail_basic,26
#
# -379,Humphrey,Mya,01/12/96,Littleton,Colorado,united_states,f,24,Mya Humphrey,0,aavail_unlimited,22
#
# -380,Dyer,Arthur,06/10/84,Oro Valley,Arizona,united_states,m,35,Arthur Dyer,0,aavail_premium,21
#
# -381,Cobb,Arian,11/13/86,Coachella,California,united_states,m,33,Arian Cobb,0,aavail_premium,18
#
# -382,Baxter,Elizabeth,05/27/78,Northglenn,Colorado,united_states,f,41,Elizabeth Baxter,0,aavail_premium,13
#
# -383,Stanton,Gabriella,05/16/98,Smyrna,Tennessee,united_states,f,21,Gabriella Stanton,0,aavail_unlimited,25
#
# -384,Petersen,Dayana,11/09/98,Moore,Oklahoma,united_states,f,21,Dayana Petersen,0,aavail_unlimited,24
#
# -385,Hoover,Vienna,09/11/95,singapore,,singapore,f,24,Vienna Hoover,0,aavail_basic,14
#
# -386,Carr,Egypt,05/01/02,Annapolis,Maryland,united_states,f,17,Egypt Carr,0,aavail_unlimited,20
#
# -387,Burgess,Keith,11/22/02,Farmington,New Mexico,united_states,m,17,Keith Burgess,1,aavail_unlimited,16
#
# -388,Galindo,Jaxtyn,04/25/99,Sparks,Nevada,united_states,m,20,Jaxtyn Galindo,0,aavail_basic,24
#
# -389,Scott,Jada,11/25/72,Lubbock,Texas,united_states,f,47,Jada Scott,1,aavail_premium,19
#
# -390,Hutchinson,Kaiya,01/06/95,singapore,,singapore,f,25,Kaiya Hutchinson,0,aavail_premium,3
#
# -391,Acevedo,Kaylee,03/06/99,singapore,,singapore,f,21,Kaylee Acevedo,1,aavail_unlimited,20
#
# -392,Morrow,Bryce,03/22/92,Madison,Wisconsin,united_states,m,27,Bryce Morrow,1,aavail_basic,19
#
# -393,Mack,Gatlin,06/25/93,Arcadia,California,united_states,m,26,Gatlin Mack,0,aavail_premium,16
#
# -394,Shaffer,Selena,11/10/96,singapore,,singapore,f,23,Selena Shaffer,1,aavail_basic,21
#
# -395,Fleming,Caleb,03/12/96,singapore,,singapore,m,23,Caleb Fleming,0,aavail_unlimited,12
#
# -396,Morse,Liliana,11/01/96,Palm Beach Gardens,Florida,united_states,f,23,Liliana Morse,0,aavail_premium,21
#
# -397,Huffman,Eleanor,08/29/97,singapore,,singapore,f,22,Eleanor Huffman,1,aavail_unlimited,10
#
# -398,Oneill,Emanuel,09/08/85,singapore,,singapore,m,34,Emanuel Oneill,1,aavail_premium,9
#
# -399,Hampton,Arabella,02/02/80,Tulare,California,united_states,f,40,Arabella Hampton,0,aavail_unlimited,24
#
# -400,Watson,Siena,07/01/98,Concord,New Hampshire,united_states,f,21,Siena Watson,0,aavail_premium,23
#
# -401,Hill,Brodie,11/30/98,singapore,,singapore,m,21,Brodie Hill,0,aavail_basic,15
#
# -402,Rivers,Joanna,06/14/71,St. Louis Park,Minnesota,united_states,f,48,Joanna Rivers,0,aavail_premium,19
#
# -403,Sanders,Ben,11/14/89,Joliet,Illinois,united_states,m,30,Ben Sanders,0,aavail_unlimited,24
#
# -404,Mcdaniel,Ember,07/09/00,singapore,,singapore,f,19,Ember Mcdaniel,1,aavail_unlimited,16
#
# -405,Koch,Eugene,11/18/78,Oakland Park,Florida,united_states,m,41,Eugene Koch,0,aavail_unlimited,23
#
# -406,Greer,Greta,01/11/05,singapore,,singapore,f,15,Greta Greer,0,aavail_premium,9
#
# -407,Pugh,Camdyn,04/16/82,Deltona,Florida,united_states,m,37,Camdyn Pugh,1,aavail_premium,20
#
# -408,Gibbs,Gary,07/11/78,San Buenaventura (Ventura),California,united_states,m,41,Gary Gibbs,0,aavail_basic,19
#
# -409,Larson,Lilian,03/21/94,Port Arthur,Texas,united_states,f,25,Lilian Larson,0,aavail_premium,18
#
# -410,Powers,Gunnar,07/17/75,Lancaster,California,united_states,m,44,Gunnar Powers,0,aavail_basic,16
#
# -411,Alfaro,Brecken,07/05/97,Manhattan,Kansas,united_states,m,22,Brecken Alfaro,0,aavail_basic,24
#
# -412,Fowler,Carolyn,01/05/79,singapore,,singapore,f,41,Carolyn Fowler,1,aavail_premium,12
#
# -413,Coleman,Nadia,09/29/97,singapore,,singapore,f,22,Nadia Coleman,0,aavail_basic,21
#
# -414,Dougherty,Ahmad,01/03/86,Bremerton,Washington,united_states,m,34,Ahmad Dougherty,0,aavail_premium,17
#
# -415,Schaefer,Alianna,08/31/96,Rowlett,Texas,united_states,f,23,Alianna Schaefer,0,aavail_unlimited,20
#
# -416,Cherry,Jacoby,05/04/99,Chelsea,Massachusetts,united_states,m,20,Jacoby Cherry,0,aavail_basic,12
#
# -417,Meadows,Jensen,12/14/00,Oxnard,California,united_states,m,19,Jensen Meadows,0,aavail_premium,23
#
# -418,Rojas,Remington,04/19/82,Oakland,California,united_states,m,37,Remington Rojas,0,aavail_basic,21
#
# -419,Graves,Rebekah,04/02/70,Gaithersburg,Maryland,united_states,f,49,Rebekah Graves,0,aavail_basic,14
#
# -420,Zhang,Jazmine,01/22/78,Plantation,Florida,united_states,f,42,Jazmine Zhang,0,aavail_premium,21
#
# -421,Mcmillan,Sarah,12/06/74,Redding,California,united_states,f,45,Sarah Mcmillan,1,aavail_unlimited,25
#
# -422,Macias,Leia,10/05/98,singapore,,singapore,f,21,Leia Macias,0,aavail_basic,19
#
# -423,Kane,Erick,11/17/93,singapore,,singapore,m,26,Erick Kane,1,aavail_basic,20
#
# -424,Wolfe,Jamal,03/17/01,singapore,,singapore,m,18,Jamal Wolfe,1,aavail_premium,17
#
# -425,Barr,Myles,09/09/05,singapore,,singapore,m,14,Myles Barr,1,aavail_basic,19
#
# -426,Douglas,Dangelo,08/13/99,Milford,Connecticut,united_states,m,20,Dangelo Douglas,0,aavail_unlimited,20
#
# -427,Stout,Case,10/10/94,singapore,,singapore,m,25,Case Stout,0,aavail_basic,20
#
# -428,Cameron,Melissa,12/05/02,Virginia Beach,Virginia,united_states,f,17,Melissa Cameron,0,aavail_premium,21
#
# -429,Ruiz,Nathan,02/04/02,singapore,,singapore,m,18,Nathan Ruiz,1,aavail_premium,14
#
# -430,Becker,Cameron,10/09/96,singapore,,singapore,m,23,Cameron Becker,0,aavail_basic,20
#
# -431,Benton,Houston,04/05/89,Elizabeth,New Jersey,united_states,m,30,Houston Benton,0,aavail_basic,25
#
# -432,Craig,Kiana,03/27/77,Jackson,Tennessee,united_states,f,42,Kiana Craig,0,aavail_unlimited,22
#
# -433,Cline,Alison,12/26/74,singapore,,singapore,f,45,Alison Cline,1,aavail_basic,18
#
# -434,Daniels,Cullen,12/11/81,Dayton,Ohio,united_states,m,38,Cullen Daniels,0,aavail_premium,23
#
# -435,Buck,Lawrence,04/02/01,Springfield,Oregon,united_states,m,18,Lawrence Buck,0,aavail_unlimited,18
#
# -436,Barry,Jaylene,11/20/01,Brownsville,Texas,united_states,f,18,Jaylene Barry,1,aavail_basic,20
#
# -437,Finley,Cassius,11/19/84,singapore,,singapore,m,35,Cassius Finley,1,aavail_unlimited,30
#
# -438,Melendez,Milena,02/09/97,singapore,,singapore,f,23,Milena Melendez,1,aavail_unlimited,18
#
# -439,Glenn,Maggie,07/23/93,Leander,Texas,united_states,f,26,Maggie Glenn,0,aavail_premium,19
#
# -440,Salas,Nolan,09/14/99,singapore,,singapore,m,20,Nolan Salas,0,aavail_premium,14
#
# -441,Howell,Ricardo,04/23/02,singapore,,singapore,m,17,Ricardo Howell,0,aavail_premium,22
#
# -442,Hunt,Judith,10/31/96,O'Fallon,Missouri,united_states,f,23,Judith Hunt,0,aavail_premium,11
#
# -443,Cooper,Alvin,01/19/96,Fairfield,California,united_states,m,24,Alvin Cooper,1,aavail_unlimited,23
#
# -444,Roth,Adrian,07/15/92,Fresno,California,united_states,m,27,Adrian Roth,0,aavail_unlimited,22
#
# -445,Mcfarland,Adeline,12/09/95,Rocklin,California,united_states,f,24,Adeline Mcfarland,0,aavail_unlimited,23
#
# -446,Hernandez,Iris,07/18/95,Aurora,Colorado,united_states,f,24,Iris Hernandez,0,aavail_premium,25
#
# -447,Roberts,Kimber,06/11/74,Rockwall,Texas,united_states,f,45,Kimber Roberts,0,aavail_basic,25
#
# -448,Ayala,Raina,10/17/98,singapore,,singapore,f,21,Raina Ayala,1,aavail_unlimited,15
#
# -449,Mccormick,Moshe,10/20/90,Pontiac,Michigan,united_states,m,29,Moshe Mccormick,0,aavail_premium,19
#
# -450,Watkins,Kase,06/25/72,Weymouth Town,Massachusetts,united_states,m,47,Kase Watkins,0,aavail_basic,18
#
# -451,Garrison,Helena,10/29/98,singapore,,singapore,f,21,Helena Garrison,0,aavail_basic,15
#
# -452,Crane,Ace,05/28/99,Roswell,Georgia,united_states,m,20,Ace Crane,0,aavail_premium,16
#
# -453,Butler,George,12/28/92,singapore,,singapore,m,27,George Butler,0,aavail_basic,20
#
# -454,Wilcox,Mallory,04/05/01,singapore,,singapore,f,18,Mallory Wilcox,1,aavail_premium,11
#
# -455,Bravo,Nehemiah,03/16/03,Kentwood,Michigan,united_states,m,16,Nehemiah Bravo,0,aavail_basic,24
#
# -456,Davis,Tadeo,07/13/84,Stonecrest,Georgia,united_states,m,35,Tadeo Davis,0,aavail_unlimited,24
#
# -457,Castillo,Kellen,04/16/97,Dearborn,Michigan,united_states,m,22,Kellen Castillo,0,aavail_premium,25
#
# -458,Garcia,Kevin,03/15/97,Bridgeport,Connecticut,united_states,m,22,Kevin Garcia,0,aavail_premium,12
#
# -459,Vaughan,Noah,01/18/99,singapore,,singapore,m,21,Noah Vaughan,1,aavail_premium,12
#
# -460,Berry,Damien,01/08/95,East Lansing,Michigan,united_states,m,25,Damien Berry,1,aavail_basic,23
#
# -461,Perkins,Nixon,01/17/01,singapore,,singapore,m,19,Nixon Perkins,1,aavail_basic,21
#
# -462,Tang,Malaya,01/14/98,Montebello,California,united_states,f,22,Malaya Tang,0,aavail_basic,18
#
# -463,Acosta,Raelyn,01/26/99,Great Falls,Montana,united_states,f,21,Raelyn Acosta,0,aavail_basic,24
#
# -464,Pierce,Asa,12/13/00,Minneapolis,Minnesota,united_states,m,19,Asa Pierce,0,aavail_premium,23
#
# -465,Cox,Amanda,06/13/97,New Braunfels,Texas,united_states,f,22,Amanda Cox,0,aavail_basic,25
#
# -466,Christian,Ridge,07/20/94,Iowa City,Iowa,united_states,m,25,Ridge Christian,0,aavail_basic,23
#
# -467,Kaur,Kylo,05/20/82,singapore,,singapore,m,37,Kylo Kaur,0,aavail_premium,17
#
# -468,Bennett,Kayla,06/09/91,singapore,,singapore,f,28,Kayla Bennett,0,aavail_basic,2
#
# -469,Morris,Atticus,05/21/95,Orem,Utah,united_states,m,24,Atticus Morris,0,aavail_basic,21
#
# -470,Arroyo,Catalina,07/31/05,Gilroy,California,united_states,f,14,Catalina Arroyo,0,aavail_basic,18
#
# -471,Waller,Kamari,03/17/80,West Covina,California,united_states,m,39,Kamari Waller,0,aavail_unlimited,23
#
# -472,Webster,Nancy,07/08/97,singapore,,singapore,f,22,Nancy Webster,1,aavail_basic,12
#
# -473,Rivera,Ali,10/19/97,Florence,Alabama,united_states,m,22,Ali Rivera,0,aavail_premium,26
#
# -474,Middleton,Alondra,12/12/69,singapore,,singapore,f,50,Alondra Middleton,1,aavail_premium,18
#
# -475,Compton,Braylen,04/23/76,singapore,,singapore,m,43,Braylen Compton,0,aavail_basic,21
#
# -476,Stewart,Evelynn,03/24/94,Davis,California,united_states,f,25,Evelynn Stewart,0,aavail_unlimited,24
#
# -477,Hoffman,Emmitt,11/28/96,Chicopee,Massachusetts,united_states,m,23,Emmitt Hoffman,0,aavail_basic,21
#
# -478,Anderson,Bobby,11/03/87,singapore,,singapore,m,32,Bobby Anderson,1,aavail_premium,20
#
# -479,Owen,Ivanna,04/24/80,Hoboken,New Jersey,united_states,f,39,Ivanna Owen,0,aavail_premium,20
#
# -480,Liu,Maddux,08/21/80,singapore,,singapore,m,39,Maddux Liu,1,aavail_basic,25
#
# -481,Quinn,Regina,07/12/93,singapore,,singapore,f,26,Regina Quinn,1,aavail_unlimited,26
#
# -482,Walls,Raquel,04/02/96,Winter Garden,Florida,united_states,f,23,Raquel Walls,0,aavail_basic,19
#
# -483,Gordon,Kendall,01/04/93,Miami Beach,Florida,united_states,m,27,Kendall Gordon,1,aavail_basic,22
#
# -484,Whitaker,Sierra,05/31/86,singapore,,singapore,f,33,Sierra Whitaker,1,aavail_basic,17
#
# -485,Santiago,Angelo,07/22/98,singapore,,singapore,m,21,Angelo Santiago,0,aavail_basic,21
#
# -486,Delarosa,Averie,02/04/98,singapore,,singapore,f,22,Averie Delarosa,1,aavail_premium,22
#
# -487,Terry,Bentley,12/28/80,Bayonne,New Jersey,united_states,m,39,Bentley Terry,0,aavail_premium,20
#
# -488,Pearson,Henrik,01/17/96,singapore,,singapore,m,24,Henrik Pearson,1,aavail_unlimited,14
#
# -489,Wood,Pearl,09/07/81,singapore,,singapore,f,38,Pearl Wood,0,aavail_basic,20
#
# -490,Jones,Kelsey,02/19/99,singapore,,singapore,f,21,Kelsey Jones,0,aavail_basic,16
#
# -491,Burch,Terrell,08/19/99,singapore,,singapore,m,20,Terrell Burch,1,aavail_premium,14
#
# ...
#
# +336,Schwartz,Rhys,03/03/95,singapore,,singapore,m,25,Rhys Schwartz,0.0,aavail_basic,21
#
# +337,Moss,Helen,07/02/73,singapore,,singapore,f,46,Helen Moss,0.0,aavail_basic,20
#
# +338,Edwards,Talia,06/04/85,Biloxi,Mississippi,united_states,f,34,Talia Edwards,0.0,aavail_premium,22
#
# +339,Orr,Dawson,06/20/97,singapore,,singapore,m,22,Dawson Orr,1.0,aavail_basic,22
#
# +340,Bentley,Yosef,01/22/74,singapore,,singapore,m,46,Yosef Bentley,0.0,aavail_basic,12
#
# +341,Barnett,Cesar,12/03/91,singapore,,singapore,m,28,Cesar Barnett,0.0,aavail_unlimited,16
#
# +342,Trejo,Atlas,05/27/95,singapore,,singapore,m,24,Atlas Trejo,1.0,aavail_basic,9
#
# +343,Reese,Roger,06/02/98,Loveland,Colorado,united_states,m,21,Roger Reese,0.0,aavail_basic,6
#
# +344,Warren,Frank,05/20/83,Kokomo,Indiana,united_states,m,36,Frank Warren,0.0,aavail_basic,23
#
# +345,Frederick,Edwin,10/19/66,Culver City,California,united_states,m,53,Edwin Frederick,0.0,aavail_premium,24
#
# +346,Pacheco,Ana,09/21/95,Midland,Michigan,united_states,f,24,Ana Pacheco,1.0,aavail_unlimited,20
#
# +347,Bradford,Noemi,05/29/02,singapore,,singapore,f,17,Noemi Bradford,1.0,aavail_unlimited,23
#
# +348,Giles,Duke,09/20/97,Lake Elsinore,California,united_states,m,22,Duke Giles,0.0,aavail_premium,24
#
# +349,Santos,Kaiser,06/04/69,Eden Prairie,Minnesota,united_states,m,50,Kaiser Santos,1.0,aavail_premium,21
#
# +350,Norris,Carly,12/30/80,Jupiter,Florida,united_states,f,39,Carly Norris,1.0,aavail_basic,24
#
# +351,Flowers,Cedric,02/26/96,Athens-Clarke County,Georgia,united_states,m,24,Cedric Flowers,0.0,aavail_unlimited,22
#
# +352,Odonnell,Emilia,02/01/86,Hackensack,New Jersey,united_states,f,34,Emilia Odonnell,0.0,aavail_unlimited,21
#
# +353,Clements,Iliana,07/21/86,Sacramento,California,united_states,f,33,Iliana Clements,0.0,aavail_basic,13
#
# +354,Lowery,Albert,04/06/97,Idaho Falls,Idaho,united_states,m,22,Albert Lowery,0.0,aavail_premium,18
#
# +355,Mccarty,Casen,06/21/98,New Bedford,Massachusetts,united_states,m,21,Casen Mccarty,1.0,aavail_unlimited,25
#
# +356,Moses,Emmalyn,09/14/00,Taylor,Michigan,united_states,f,19,Emmalyn Moses,1.0,aavail_basic,19
#
# +357,Lu,Miguel,03/26/99,Methuen,Massachusetts,united_states,m,20,Miguel Lu,0.0,aavail_basic,22
#
# +358,Mcbride,Jude,09/09/97,singapore,,singapore,m,22,Jude Mcbride,1.0,aavail_premium,4
#
# +359,Durham,Irene,08/28/00,Mount Vernon,New York,united_states,f,19,Irene Durham,0.0,aavail_unlimited,25
#
# +360,Mcguire,Markus,11/19/74,Hialeah,Florida,united_states,m,45,Markus Mcguire,0.0,aavail_unlimited,17
#
# +361,Serrano,Fernando,08/10/92,San Clemente,California,united_states,m,27,Fernando Serrano,0.0,aavail_premium,18
#
# +362,Moyer,Rowan,03/28/05,Cedar Rapids,Iowa,united_states,f,14,Rowan Moyer,0.0,aavail_basic,3
#
# +363,Herrera,Isaiah,02/18/98,North Lauderdale,Florida,united_states,m,22,Isaiah Herrera,0.0,aavail_premium,17
#
# +364,King,Trace,08/21/97,Delano,California,united_states,m,22,Trace King,0.0,aavail_basic,22
#
# +365,Hurst,Angel,07/10/95,Belleville,Illinois,united_states,f,24,Angel Hurst,0.0,aavail_unlimited,17
#
# +366,Palacios,Enrique,05/22/00,singapore,,singapore,m,19,Enrique Palacios,1.0,aavail_basic,8
#
# +367,Dudley,Lennox,11/07/94,singapore,,singapore,f,25,Lennox Dudley,0.0,aavail_basic,18
#
# +368,Lester,Louisa,10/16/01,Gulfport,Mississippi,united_states,f,18,Louisa Lester,0.0,aavail_premium,20
#
# +369,Mayo,Bryson,07/27/99,DeSoto,Texas,united_states,m,20,Bryson Mayo,0.0,aavail_unlimited,26
#
# +370,Tanner,Charles,03/29/95,singapore,,singapore,m,24,Charles Tanner,0.0,aavail_premium,20
#
# +371,Monroe,Camilo,01/26/80,singapore,,singapore,m,40,Camilo Monroe,1.0,aavail_unlimited,13
#
# +372,Farley,Mohammed,07/27/94,New Orleans,Louisiana,united_states,m,25,Mohammed Farley,0.0,aavail_basic,22
#
# +373,Hail,Tristian,03/06/01,Mobile,Alabama,united_states,m,19,Tristian Hail,0.0,aavail_premium,20
#
# +374,Hardin,Aliya,06/14/73,Albany,New York,united_states,f,46,Aliya Hardin,1.0,aavail_premium,22
#
# +375,Dickson,Daniel,05/13/89,Yucaipa,California,united_states,m,30,Daniel Dickson,0.0,aavail_basic,8
#
# +376,Leacock,Julius,05/22/00,Yuma,Arizona,united_states,m,19,Julius Leacock,0.0,aavail_unlimited,20
#
# +377,Velazquez,Zariyah,12/23/66,Fort Lauderdale,Florida,united_states,f,53,Zariyah Velazquez,0.0,aavail_unlimited,17
#
# +378,Magana,Lorenzo,04/14/01,La Mirada,California,united_states,m,18,Lorenzo Magana,0.0,aavail_basic,26
#
# +379,Humphrey,Mya,01/12/96,Littleton,Colorado,united_states,f,24,Mya Humphrey,0.0,aavail_unlimited,22
#
# +380,Dyer,Arthur,06/10/84,Oro Valley,Arizona,united_states,m,35,Arthur Dyer,0.0,aavail_premium,21
#
# +381,Cobb,Arian,11/13/86,Coachella,California,united_states,m,33,Arian Cobb,0.0,aavail_premium,18
#
# +382,Baxter,Elizabeth,05/27/78,Northglenn,Colorado,united_states,f,41,Elizabeth Baxter,0.0,aavail_premium,13
#
# +383,Stanton,Gabriella,05/16/98,Smyrna,Tennessee,united_states,f,21,Gabriella Stanton,0.0,aavail_unlimited,25
#
# +384,Petersen,Dayana,11/09/98,Moore,Oklahoma,united_states,f,21,Dayana Petersen,0.0,aavail_unlimited,24
#
# +385,Hoover,Vienna,09/11/95,singapore,,singapore,f,24,Vienna Hoover,0.0,aavail_basic,14
#
# +386,Carr,Egypt,05/01/02,Annapolis,Maryland,united_states,f,17,Egypt Carr,0.0,aavail_unlimited,20
#
# +387,Burgess,Keith,11/22/02,Farmington,New Mexico,united_states,m,17,Keith Burgess,1.0,aavail_unlimited,16
#
# +388,Galindo,Jaxtyn,04/25/99,Sparks,Nevada,united_states,m,20,Jaxtyn Galindo,0.0,aavail_basic,24
#
# +389,Scott,Jada,11/25/72,Lubbock,Texas,united_states,f,47,Jada Scott,1.0,aavail_premium,19
#
# +390,Hutchinson,Kaiya,01/06/95,singapore,,singapore,f,25,Kaiya Hutchinson,0.0,aavail_premium,3
#
# +391,Acevedo,Kaylee,03/06/99,singapore,,singapore,f,21,Kaylee Acevedo,1.0,aavail_unlimited,20
#
# +392,Morrow,Bryce,03/22/92,Madison,Wisconsin,united_states,m,27,Bryce Morrow,1.0,aavail_basic,19
#
# +393,Mack,Gatlin,06/25/93,Arcadia,California,united_states,m,26,Gatlin Mack,0.0,aavail_premium,16
#
# +394,Shaffer,Selena,11/10/96,singapore,,singapore,f,23,Selena Shaffer,1.0,aavail_basic,21
#
# +395,Fleming,Caleb,03/12/96,singapore,,singapore,m,23,Caleb Fleming,0.0,aavail_unlimited,12
#
# +396,Morse,Liliana,11/01/96,Palm Beach Gardens,Florida,united_states,f,23,Liliana Morse,0.0,aavail_premium,21
#
# +397,Huffman,Eleanor,08/29/97,singapore,,singapore,f,22,Eleanor Huffman,1.0,aavail_unlimited,10
#
# +398,Oneill,Emanuel,09/08/85,singapore,,singapore,m,34,Emanuel Oneill,1.0,aavail_premium,9
#
# +399,Hampton,Arabella,02/02/80,Tulare,California,united_states,f,40,Arabella Hampton,0.0,aavail_unlimited,24
#
# +400,Watson,Siena,07/01/98,Concord,New Hampshire,united_states,f,21,Siena Watson,0.0,aavail_premium,23
#
# +401,Hill,Brodie,11/30/98,singapore,,singapore,m,21,Brodie Hill,0.0,aavail_basic,15
#
# +402,Rivers,Joanna,06/14/71,St. Louis Park,Minnesota,united_states,f,48,Joanna Rivers,0.0,aavail_premium,19
#
# +403,Sanders,Ben,11/14/89,Joliet,Illinois,united_states,m,30,Ben Sanders,0.0,aavail_unlimited,24
#
# +404,Mcdaniel,Ember,07/09/00,singapore,,singapore,f,19,Ember Mcdaniel,1.0,aavail_unlimited,16
#
# +405,Koch,Eugene,11/18/78,Oakland Park,Florida,united_states,m,41,Eugene Koch,0.0,aavail_unlimited,23
#
# +406,Greer,Greta,01/11/05,singapore,,singapore,f,15,Greta Greer,0.0,aavail_premium,9
#
# +407,Pugh,Camdyn,04/16/82,Deltona,Florida,united_states,m,37,Camdyn Pugh,1.0,aavail_premium,20
#
# +408,Gibbs,Gary,07/11/78,San Buenaventura (Ventura),California,united_states,m,41,Gary Gibbs,0.0,aavail_basic,19
#
# +409,Larson,Lilian,03/21/94,Port Arthur,Texas,united_states,f,25,Lilian Larson,0.0,aavail_premium,18
#
# +410,Powers,Gunnar,07/17/75,Lancaster,California,united_states,m,44,Gunnar Powers,0.0,aavail_basic,16
#
# +411,Alfaro,Brecken,07/05/97,Manhattan,Kansas,united_states,m,22,Brecken Alfaro,0.0,aavail_basic,24
#
# +412,Fowler,Carolyn,01/05/79,singapore,,singapore,f,41,Carolyn Fowler,1.0,aavail_premium,12
#
# +413,Coleman,Nadia,09/29/97,singapore,,singapore,f,22,Nadia Coleman,0.0,aavail_basic,21
#
# +414,Dougherty,Ahmad,01/03/86,Bremerton,Washington,united_states,m,34,Ahmad Dougherty,0.0,aavail_premium,17
#
# +415,Schaefer,Alianna,08/31/96,Rowlett,Texas,united_states,f,23,Alianna Schaefer,0.0,aavail_unlimited,20
#
# +416,Cherry,Jacoby,05/04/99,Chelsea,Massachusetts,united_states,m,20,Jacoby Cherry,0.0,aavail_basic,12
#
# +417,Meadows,Jensen,12/14/00,Oxnard,California,united_states,m,19,Jensen Meadows,0.0,aavail_premium,23
#
# +418,Rojas,Remington,04/19/82,Oakland,California,united_states,m,37,Remington Rojas,0.0,aavail_basic,21
#
# +419,Graves,Rebekah,04/02/70,Gaithersburg,Maryland,united_states,f,49,Rebekah Graves,0.0,aavail_basic,14
#
# +420,Zhang,Jazmine,01/22/78,Plantation,Florida,united_states,f,42,Jazmine Zhang,0.0,aavail_premium,21
#
# +421,Mcmillan,Sarah,12/06/74,Redding,California,united_states,f,45,Sarah Mcmillan,1.0,aavail_unlimited,25
#
# +422,Macias,Leia,10/05/98,singapore,,singapore,f,21,Leia Macias,0.0,aavail_basic,19
#
# +423,Kane,Erick,11/17/93,singapore,,singapore,m,26,Erick Kane,1.0,aavail_basic,20
#
# +424,Wolfe,Jamal,03/17/01,singapore,,singapore,m,18,Jamal Wolfe,1.0,aavail_premium,17
#
# +425,Barr,Myles,09/09/05,singapore,,singapore,m,14,Myles Barr,1.0,aavail_basic,19
#
# +426,Douglas,Dangelo,08/13/99,Milford,Connecticut,united_states,m,20,Dangelo Douglas,0.0,aavail_unlimited,20
#
# +427,Stout,Case,10/10/94,singapore,,singapore,m,25,Case Stout,0.0,aavail_basic,20
#
# +428,Cameron,Melissa,12/05/02,Virginia Beach,Virginia,united_states,f,17,Melissa Cameron,0.0,aavail_premium,21
#
# +429,Ruiz,Nathan,02/04/02,singapore,,singapore,m,18,Nathan Ruiz,1.0,aavail_premium,14
#
# +430,Becker,Cameron,10/09/96,singapore,,singapore,m,23,Cameron Becker,0.0,aavail_basic,20
#
# +431,Benton,Houston,04/05/89,Elizabeth,New Jersey,united_states,m,30,Houston Benton,0.0,aavail_basic,25
#
# +432,Craig,Kiana,03/27/77,Jackson,Tennessee,united_states,f,42,Kiana Craig,0.0,aavail_unlimited,22
#
# +433,Cline,Alison,12/26/74,singapore,,singapore,f,45,Alison Cline,1.0,aavail_basic,18
#
# +434,Daniels,Cullen,12/11/81,Dayton,Ohio,united_states,m,38,Cullen Daniels,0.0,aavail_premium,23
#
# +435,Buck,Lawrence,04/02/01,Springfield,Oregon,united_states,m,18,Lawrence Buck,0.0,aavail_unlimited,18
#
# +436,Barry,Jaylene,11/20/01,Brownsville,Texas,united_states,f,18,Jaylene Barry,1.0,aavail_basic,20
#
# +437,Finley,Cassius,11/19/84,singapore,,singapore,m,35,Cassius Finley,1.0,aavail_unlimited,30
#
# +438,Melendez,Milena,02/09/97,singapore,,singapore,f,23,Milena Melendez,1.0,aavail_unlimited,18
#
# +439,Glenn,Maggie,07/23/93,Leander,Texas,united_states,f,26,Maggie Glenn,0.0,aavail_premium,19
#
# +440,Salas,Nolan,09/14/99,singapore,,singapore,m,20,Nolan Salas,0.0,aavail_premium,14
#
# +441,Howell,Ricardo,04/23/02,singapore,,singapore,m,17,Ricardo Howell,0.0,aavail_premium,22
#
# +442,Hunt,Judith,10/31/96,O'Fallon,Missouri,united_states,f,23,Judith Hunt,0.0,aavail_premium,11
#
# +443,Cooper,Alvin,01/19/96,Fairfield,California,united_states,m,24,Alvin Cooper,1.0,aavail_unlimited,23
#
# +444,Roth,Adrian,07/15/92,Fresno,California,united_states,m,27,Adrian Roth,0.0,aavail_unlimited,22
#
# +445,Mcfarland,Adeline,12/09/95,Rocklin,California,united_states,f,24,Adeline Mcfarland,0.0,aavail_unlimited,23
#
# +446,Hernandez,Iris,07/18/95,Aurora,Colorado,united_states,f,24,Iris Hernandez,0.0,aavail_premium,25
#
# +447,Roberts,Kimber,06/11/74,Rockwall,Texas,united_states,f,45,Kimber Roberts,0.0,aavail_basic,25
#
# +448,Ayala,Raina,10/17/98,singapore,,singapore,f,21,Raina Ayala,1.0,aavail_unlimited,15
#
# +449,Mccormick,Moshe,10/20/90,Pontiac,Michigan,united_states,m,29,Moshe Mccormick,0.0,aavail_premium,19
#
# +450,Watkins,Kase,06/25/72,Weymouth Town,Massachusetts,united_states,m,47,Kase Watkins,0.0,aavail_basic,18
#
# +451,Garrison,Helena,10/29/98,singapore,,singapore,f,21,Helena Garrison,0.0,aavail_basic,15
#
# +452,Crane,Ace,05/28/99,Roswell,Georgia,united_states,m,20,Ace Crane,0.0,aavail_premium,16
#
# +453,Butler,George,12/28/92,singapore,,singapore,m,27,George Butler,0.0,aavail_basic,20
#
# +454,Wilcox,Mallory,04/05/01,singapore,,singapore,f,18,Mallory Wilcox,1.0,aavail_premium,11
#
# +455,Bravo,Nehemiah,03/16/03,Kentwood,Michigan,united_states,m,16,Nehemiah Bravo,0.0,aavail_basic,24
#
# +456,Davis,Tadeo,07/13/84,Stonecrest,Georgia,united_states,m,35,Tadeo Davis,0.0,aavail_unlimited,24
#
# +457,Castillo,Kellen,04/16/97,Dearborn,Michigan,united_states,m,22,Kellen Castillo,0.0,aavail_premium,25
#
# +458,Garcia,Kevin,03/15/97,Bridgeport,Connecticut,united_states,m,22,Kevin Garcia,0.0,aavail_premium,12
#
# +459,Vaughan,Noah,01/18/99,singapore,,singapore,m,21,Noah Vaughan,1.0,aavail_premium,12
#
# +460,Berry,Damien,01/08/95,East Lansing,Michigan,united_states,m,25,Damien Berry,1.0,aavail_basic,23
#
# +461,Perkins,Nixon,01/17/01,singapore,,singapore,m,19,Nixon Perkins,1.0,aavail_basic,21
#
# +462,Tang,Malaya,01/14/98,Montebello,California,united_states,f,22,Malaya Tang,0.0,aavail_basic,18
#
# +463,Acosta,Raelyn,01/26/99,Great Falls,Montana,united_states,f,21,Raelyn Acosta,0.0,aavail_basic,24
#
# +464,Pierce,Asa,12/13/00,Minneapolis,Minnesota,united_states,m,19,Asa Pierce,0.0,aavail_premium,23
#
# +465,Cox,Amanda,06/13/97,New Braunfels,Texas,united_states,f,22,Amanda Cox,0.0,aavail_basic,25
#
# +466,Christian,Ridge,07/20/94,Iowa City,Iowa,united_states,m,25,Ridge Christian,0.0,aavail_basic,23
#
# +467,Kaur,Kylo,05/20/82,singapore,,singapore,m,37,Kylo Kaur,0.0,aavail_premium,17
#
# +468,Bennett,Kayla,06/09/91,singapore,,singapore,f,28,Kayla Bennett,0.0,aavail_basic,2
#
# +469,Morris,Atticus,05/21/95,Orem,Utah,united_states,m,24,Atticus Morris,0.0,aavail_basic,21
#
# +470,Arroyo,Catalina,07/31/05,Gilroy,California,united_states,f,14,Catalina Arroyo,0.0,aavail_basic,18
#
# +471,Waller,Kamari,03/17/80,West Covina,California,united_states,m,39,Kamari Waller,0.0,aavail_unlimited,23
#
# +472,Webster,Nancy,07/08/97,singapore,,singapore,f,22,Nancy Webster,1.0,aavail_basic,12
#
# +473,Rivera,Ali,10/19/97,Florence,Alabama,united_states,m,22,Ali Rivera,0.0,aavail_premium,26
#
# +474,Middleton,Alondra,12/12/69,singapore,,singapore,f,50,Alondra Middleton,1.0,aavail_premium,18
#
# +475,Compton,Braylen,04/23/76,singapore,,singapore,m,43,Braylen Compton,0.0,aavail_basic,21
#
# +476,Stewart,Evelynn,03/24/94,Davis,California,united_states,f,25,Evelynn Stewart,0.0,aavail_unlimited,24
#
# +477,Hoffman,Emmitt,11/28/96,Chicopee,Massachusetts,united_states,m,23,Emmitt Hoffman,0.0,aavail_basic,21
#
# +478,Anderson,Bobby,11/03/87,singapore,,singapore,m,32,Bobby Anderson,1.0,aavail_premium,20
#
# +479,Owen,Ivanna,04/24/80,Hoboken,New Jersey,united_states,f,39,Ivanna Owen,0.0,aavail_premium,20
#
# +480,Liu,Maddux,08/21/80,singapore,,singapore,m,39,Maddux Liu,1.0,aavail_basic,25
#
# +481,Quinn,Regina,07/12/93,singapore,,singapore,f,26,Regina Quinn,1.0,aavail_unlimited,26
#
# +482,Walls,Raquel,04/02/96,Winter Garden,Florida,united_states,f,23,Raquel Walls,0.0,aavail_basic,19
#
# +483,Gordon,Kendall,01/04/93,Miami Beach,Florida,united_states,m,27,Kendall Gordon,1.0,aavail_basic,22
#
# +484,Whitaker,Sierra,05/31/86,singapore,,singapore,f,33,Sierra Whitaker,1.0,aavail_basic,17
#
# +485,Santiago,Angelo,07/22/98,singapore,,singapore,m,21,Angelo Santiago,0.0,aavail_basic,21
#
# +486,Delarosa,Averie,02/04/98,singapore,,singapore,f,22,Averie Delarosa,1.0,aavail_premium,22
#
# +487,Terry,Bentley,12/28/80,Bayonne,New Jersey,united_states,m,39,Bentley Terry,0.0,aavail_premium,20
#
# +488,Pearson,Henrik,01/17/96,singapore,,singapore,m,24,Henrik Pearson,1.0,aavail_unlimited,14
#
# +489,Wood,Pearl,09/07/81,singapore,,singapore,f,38,Pearl Wood,0.0,aavail_basic,20
#
# +490,Jones,Kelsey,02/19/99,singapore,,singapore,f,21,Kelsey Jones,0.0,aavail_basic,16
#
# +491,Burch,Terrell,08/19/99,singapore,,singapore,m,20,Terrell Burch,1.0,aavail_premium,14
#
# +492,Hull,Alaina,11/24/99,West Jordan,Utah,united_states,f,20,Alaina Hull,0.0,aavail_premium,18
#
# +493,Wang,Maverick,02/13/82,singapore,,singapore,m,38,Maverick Wang,1.0,aavail_premium,11
#
# +494,Nunez,Quincy,10/02/99,singapore,,singapore,m,20,Quincy Nunez,0.0,aavail_basic,18
#
# +495,Black,Oscar,05/12/95,Chesterfield,Missouri,united_states,m,24,Oscar Black,0.0,aavail_unlimited,23
#
# +496,Lang,Achilles,10/21/81,Palmdale,California,united_states,m,38,Achilles Lang,0.0,aavail_premium,22
#
# +497,Porter,Deacon,08/30/03,Charleston,West Virginia,united_states,m,16,Deacon Porter,0.0,aavail_premium,11

# %%
# !head ../data/aavail-streams.csv
# Out:
# customer_id,stream_id,date,subscription_stopped
# 1,1356,2018-12-01,0
# 1,1540,2018-12-04,0
# 1,1395,2018-12-11,0
# 1,1255,2018-12-22,0
# 1,1697,2018-12-23,0
# 1,1522,2019-01-04,0
# 1,1170,2019-01-06,0
# 1,1314,2019-01-11,0
# 1,1448,2019-02-07,0

# %%
# !head ../data/aavail-streams-1.csv
# Out:
# customer_id,stream_id,date,subscription_stopped
# 1,1356,2018-12-01,0
# 1,1540,2018-12-04,0
# 1,1395,2018-12-11,0
# 1,1255,2018-12-22,0
# 1,1697,2018-12-23,0
# 1,1522,2019-01-04,0
# 1,1170,2019-01-06,0
# 1,1314,2019-01-11,0
# 1,1448,2019-02-07,0

# %% [markdown]
# You will need to save your function as a file.  The following cell demonstrates how to do this from within a notebook.

# %%
# %%writefile aavail-data-ingestor.py
#!/usr/bin/env python

import os
import pandas as pd
import numpy as np
import sqlite3

data_dir = os.path.join(".","data")

pass

# %% [markdown]
# You will also need to be able to pass the file names to your function without hardcoding them into the script itself.  This is an important step towards automation.  Here are the two libraries commonly used to accomplish this in Python.
#
# * [getopt](https://docs.python.org/3/library/getopt.html)
# * [argparse](https://docs.python.org/3/library/argparse.html)

# %% [markdown]
# You may run the script you just created from the commandline directly or from within this notebook using:

# %% [markdown]
# Run the script once for each batch that you created and then load both the original and batch versions back into the notebook to check that they are the same.

# %% [markdown]
# ### QUESTION 6:
#
# **How can you improve the process?**
#
# In paragraph form or using bullets write down some of the ways that you could improve this pipeline.

# %% [markdown]
# YOUR ANSWER HERE
